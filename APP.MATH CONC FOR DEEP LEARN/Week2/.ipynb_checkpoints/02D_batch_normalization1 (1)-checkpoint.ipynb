# %% [markdown]
# # Batch Normalization on CIFAR-10
#
# In this notebook we implement batch normalization, which is an opimization method useful for deep feed-forward neural networks, such as deep CNNs. Here we implement it on a toy-model of fully-connected (dense) layers, and toy-data (CIFAR-10).
#
# In addition to Batch Normalization, we demonstrate how to implement early stopping, saving a checkpoint model, and use Keras logging for Tensorboard.
#
# The main takeaways from this notebook are to know how to implement in Keras:
# 1. Batch Normalization
# 2. Early Stopping
# 3. Saving Checkpoints
# 4. Default Keras Logs into Tensorboard
#
# Based on the [notebook](https://github.com/ageron/handson-ml3/blob/main/11_training_deep_neural_networks.ipynb) of Geron, chapter 11, exercise 8.
# Presented here in accordance with the Apache 2.0 license.

# %%
import tensorflow as tf

# %% [markdown]
# ## Get the Data
# CIFAR-10 dataset is composed of 60,000 32 × 32–pixel color images (50,000 for training, 10,000 for testing) with 10 classes (for students: what is the difference between CIFAR-10 and MNIST in that sense?).
#
# We get the data from tf.keras.datasets (similar to how we did for MNIST). This means that we get numpy array back.
#
# As seen in the [dataset description](https://keras.io/api/datasets/cifar10/), the 10 classes are:
#
# Label |	Description
# --- | ---
# 0 |	airplane
# 1 |	automobile
# 2 |	bird
# 3 |	cat
# 4 |	deer
# 5 |	dog
# 6 |	frog
# 7 |	horse
# 8 |	ship
# 9 |	truck

# %%
cifar10 = tf.keras.datasets.cifar10.load_data()
(X_train_full, y_train_full), (X_test, y_test) = cifar10

# TODO: for the students: how many images are there in the training and the validation sets?
# TODO: for the students: what does 'x' and 'y' stand for?
X_train = X_train_full[5000:]
y_train = y_train_full[5000:]
X_valid = X_train_full[:5000]
y_valid = y_train_full[:5000]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 25s 0us/step

# %% [markdown]
# ## Data Exploration

# %%
import matplotlib.pyplot as plt
plt.imshow(X_train[0])

# %%
print(y_train[0])
# Out:
# [6]

# %%
# TODO: for the students: which additional data explorations would you do?

# %% [markdown]
# ## Define the Base Model
# Here we build a DNN with 20 hidden layers of 100 neurons each.
# That's too many, but it's the point of this exercise, because it allows us to use some of the optimization techniques we learned.

# %%
# TODO: for the students: can you add comments to each line of code below explaining what it does and why?

# ?
tf.random.set_seed(42)

# ?
model = tf.keras.Sequential()
# ?
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
# ?
for _ in range(20):
    # ?
    model.add(tf.keras.layers.Dense(100,
                                    # ?
                                    activation="swish",
                                    # ?
                                    kernel_initializer="he_normal"))
# ?
model.add(tf.keras.layers.Dense(10, activation="softmax"))
# Out:
# C:\Users\wayne\anaconda3\envs\deeplearning-env\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## Define the Loss Function, Optimizer and Metrics

# %%
optimizer = tf.keras.optimizers.Nadam(learning_rate=5e-5)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

# %% [markdown]
# ## Define Callbacks for Early Stopping, Checkpoints, and Logging

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=20,
                                                     restore_best_weights=True)
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("cifar10_model.keras", save_best_only=True)

run_index = 1 # increment every time you train the model
run_logdir = f"./runs/cifar10_logs/run_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

# %% [markdown]
# ## Traing the Model
# Before start running the training, initialize Tensorboard, such that you can view the training as it progresses.

# %%
model.fit(X_train, y_train, epochs=100,
          validation_data=(X_valid, y_valid),
          callbacks=callbacks, verbose=2)
# Out:
# Epoch 1/100
# 1407/1407 - 29s - 20ms/step - accuracy: 0.1721 - loss: 4.2357 - val_accuracy: 0.2160 - val_loss: 2.2079
# Epoch 2/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.2379 - loss: 2.1011 - val_accuracy: 0.2556 - val_loss: 2.0680
# Epoch 3/100
# 1407/1407 - 15s - 10ms/step - accuracy: 0.2770 - loss: 1.9831 - val_accuracy: 0.2950 - val_loss: 1.9654
# Epoch 4/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.3064 - loss: 1.9086 - val_accuracy: 0.3244 - val_loss: 1.9132
# Epoch 5/100
# 1407/1407 - 16s - 11ms/step - accuracy: 0.3339 - loss: 1.8438 - val_accuracy: 0.3432 - val_loss: 1.8196
# Epoch 6/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.3531 - loss: 1.7973 - val_accuracy: 0.3596 - val_loss: 1.7776
# Epoch 7/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.3693 - loss: 1.7603 - val_accuracy: 0.3698 - val_loss: 1.7583
# Epoch 8/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.3825 - loss: 1.7196 - val_accuracy: 0.3914 - val_loss: 1.7147
# Epoch 9/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.3915 - loss: 1.6901 - val_accuracy: 0.3904 - val_loss: 1.6986
# Epoch 10/100
# 1407/1407 - 15s - 10ms/step - accuracy: 0.4044 - loss: 1.6581 - val_accuracy: 0.3924 - val_loss: 1.6874
# Epoch 11/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.4115 - loss: 1.6317 - val_accuracy: 0.4146 - val_loss: 1.6381
# Epoch 12/100
# 1407/1407 - 15s - 10ms/step - accuracy: 0.4203 - loss: 1.6122 - val_accuracy: 0.4234 - val_loss: 1.6064
# Epoch 13/100
# 1407/1407 - 15s - 10ms/step - accuracy: 0.4281 - loss: 1.5899 - val_accuracy: 0.4256 - val_loss: 1.6109
# Epoch 14/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.4357 - loss: 1.5700 - val_accuracy: 0.4232 - val_loss: 1.6027
# Epoch 15/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.4397 - loss: 1.5550 - val_accuracy: 0.4324 - val_loss: 1.6002
# Epoch 16/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.4468 - loss: 1.5383 - val_accuracy: 0.4382 - val_loss: 1.5843
# Epoch 17/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.4546 - loss: 1.5229 - val_accuracy: 0.4258 - val_loss: 1.5793
# Epoch 18/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.4571 - loss: 1.5106 - val_accuracy: 0.4414 - val_loss: 1.5739
# Epoch 19/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.4631 - loss: 1.4955 - val_accuracy: 0.4376 - val_loss: 1.5705
# Epoch 20/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.4666 - loss: 1.4827 - val_accuracy: 0.4442 - val_loss: 1.5738
# Epoch 21/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.4753 - loss: 1.4690 - val_accuracy: 0.4354 - val_loss: 1.5824
# Epoch 22/100
# 1407/1407 - 15s - 10ms/step - accuracy: 0.4774 - loss: 1.4576 - val_accuracy: 0.4364 - val_loss: 1.5955
# Epoch 23/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.4829 - loss: 1.4429 - val_accuracy: 0.4340 - val_loss: 1.6201
# Epoch 24/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.4870 - loss: 1.4338 - val_accuracy: 0.4378 - val_loss: 1.6129
# Epoch 25/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.4909 - loss: 1.4228 - val_accuracy: 0.4306 - val_loss: 1.6015
# Epoch 26/100
# 1407/1407 - 15s - 10ms/step - accuracy: 0.4954 - loss: 1.4112 - val_accuracy: 0.4326 - val_loss: 1.6154
# Epoch 27/100
# 1407/1407 - 15s - 10ms/step - accuracy: 0.4995 - loss: 1.4025 - val_accuracy: 0.4368 - val_loss: 1.6125
# Epoch 28/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.5031 - loss: 1.3903 - val_accuracy: 0.4322 - val_loss: 1.6093
# Epoch 29/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.5045 - loss: 1.3850 - val_accuracy: 0.4334 - val_loss: 1.6183
# Epoch 30/100
# 1407/1407 - 16s - 11ms/step - accuracy: 0.5098 - loss: 1.3737 - val_accuracy: 0.4342 - val_loss: 1.6112
# Epoch 31/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.5124 - loss: 1.3632 - val_accuracy: 0.4384 - val_loss: 1.6125
# Epoch 32/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.5145 - loss: 1.3550 - val_accuracy: 0.4330 - val_loss: 1.6127
# Epoch 33/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.5195 - loss: 1.3453 - val_accuracy: 0.4342 - val_loss: 1.6139
# Epoch 34/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.5230 - loss: 1.3356 - val_accuracy: 0.4382 - val_loss: 1.6174
# Epoch 35/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.5250 - loss: 1.3302 - val_accuracy: 0.4340 - val_loss: 1.6237
# Epoch 36/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.5258 - loss: 1.3226 - val_accuracy: 0.4340 - val_loss: 1.6250
# Epoch 37/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.5298 - loss: 1.3138 - val_accuracy: 0.4336 - val_loss: 1.6423
# Epoch 38/100
# 1407/1407 - 14s - 10ms/step - accuracy: 0.5334 - loss: 1.3077 - val_accuracy: 0.4320 - val_loss: 1.6259
# Epoch 39/100
# 1407/1407 - 15s - 11ms/step - accuracy: 0.5350 - loss: 1.3010 - val_accuracy: 0.4408 - val_loss: 1.6285

# %% [markdown]
# ### Batch Normalization

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3])) #32*32*3 RGB
for _ in range(20):
    model.add(tf.keras.layers.Dense(100, kernel_initializer="he_normal"))
    model.add(tf.keras.layers.BatchNormalization())  # Adding batch normalization
    model.add(tf.keras.layers.Activation("swish")) ####

model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.Nadam(learning_rate=5e-4)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=20,
                                                     restore_best_weights=True)
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("cifar10_bn_model.keras",
                                                         save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = f"cifar10_logs/run_bn_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

model.fit(X_train, y_train, epochs=100,
          validation_data=(X_valid, y_valid),
          callbacks=callbacks)

model.evaluate(X_valid, y_valid)
# Out:
# Epoch 1/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 53s 19ms/step - accuracy: 0.1846 - loss: 2.2170 - val_accuracy: 0.3296 - val_loss: 1.8598
# Epoch 2/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - accuracy: 0.3311 - loss: 1.8339 - val_accuracy: 0.3832 - val_loss: 1.7281
# Epoch 3/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 17ms/step - accuracy: 0.3928 - loss: 1.6953 - val_accuracy: 0.3528 - val_loss: 1.8936
# Epoch 4/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - accuracy: 0.4281 - loss: 1.6076 - val_accuracy: 0.3816 - val_loss: 1.7272
# Epoch 5/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - accuracy: 0.4595 - loss: 1.5241 - val_accuracy: 0.4050 - val_loss: 1.6758
# Epoch 6/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - accuracy: 0.4867 - loss: 1.4540 - val_accuracy: 0.3990 - val_loss: 1.6942
# Epoch 7/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - accuracy: 0.5094 - loss: 1.3913 - val_accuracy: 0.3868 - val_loss: 1.7762
# Epoch 8/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 17ms/step - accuracy: 0.5331 - loss: 1.3292 - val_accuracy: 0.3914 - val_loss: 1.7916
# Epoch 9/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - accuracy: 0.5525 - loss: 1.2748 - val_accuracy: 0.3532 - val_loss: 1.9671
# Epoch 10/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - accuracy: 0.5745 - loss: 1.2169 - val_accuracy: 0.3488 - val_loss: 2.0257
# Epoch 11/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - accuracy: 0.5915 - loss: 1.1745 - val_accuracy: 0.3598 - val_loss: 2.0057
# Epoch 12/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - accuracy: 0.6068 - loss: 1.1323 - val_accuracy: 0.3828 - val_loss: 1.9252
# Epoch 13/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - accuracy: 0.6232 - loss: 1.0874 - val_accuracy: 0.3966 - val_loss: 1.8969
# Epoch 14/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 17ms/step - accuracy: 0.6369 - loss: 1.0441 - val_accuracy: 0.3880 - val_loss: 2.0303
# Epoch 15/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - accuracy: 0.6469 - loss: 1.0172 - val_accuracy: 0.3642 - val_loss: 2.0960
# Epoch 16/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - accuracy: 0.6582 - loss: 0.9860 - val_accuracy: 0.3594 - val_loss: 2.2131
# Epoch 17/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - accuracy: 0.6686 - loss: 0.9537 - val_accuracy: 0.3668 - val_loss: 2.1098
# Epoch 18/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - accuracy: 0.6798 - loss: 0.9211 - val_accuracy: 0.3612 - val_loss: 2.2292
# Epoch 19/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - accuracy: 0.6932 - loss: 0.8902 - val_accuracy: 0.3638 - val_loss: 2.2376
# Epoch 20/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - accuracy: 0.6955 - loss: 0.8709 - val_accuracy: 0.3662 - val_loss: 2.3471
# Epoch 21/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - accuracy: 0.7074 - loss: 0.8365 - val_accuracy: 0.4004 - val_loss: 2.1634
# Epoch 22/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - accuracy: 0.7180 - loss: 0.8115 - val_accuracy: 0.3682 - val_loss: 2.4110
# Epoch 23/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 25s 18ms/step - accuracy: 0.7282 - loss: 0.7826 - val_accuracy: 0.3782 - val_loss: 2.3807
# Epoch 24/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - accuracy: 0.7337 - loss: 0.7612 - val_accuracy: 0.3440 - val_loss: 2.6015
# Epoch 25/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - accuracy: 0.7406 - loss: 0.7441 - val_accuracy: 0.3426 - val_loss: 2.6164
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4004 - loss: 1.6726
# [1.6757904291152954, 0.4050000011920929]

# %%
# 啟用 TensorBoard 擴充功能
# %load_ext tensorboard

# 使用對應 logdir 啟動 TensorBoard
# %tensorboard --logdir=cifar10_logs
# Out:
#       <iframe id="tensorboard-frame-a7ff6c414a85407b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a7ff6c414a85407b");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
