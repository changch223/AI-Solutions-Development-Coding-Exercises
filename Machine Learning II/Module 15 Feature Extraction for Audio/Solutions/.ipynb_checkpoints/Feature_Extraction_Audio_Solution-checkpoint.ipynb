# %% [markdown]
# # Feature Extraction in Audio
# ## This notebook outlines the concepts behind extracting features from audio

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# Extracting a set of features that are informative with respect to the desired properties of the original audio data
#
# Low-level features to construct a higher-level of understanding
#
# Need to extract audio features capable of discriminating between different audio classes i.e. speakers, emotions, genres

# %% [markdown]
# ### Features
# - Short-term Windowing (Framing)
#     - Energy
#     - Spectral Centroid
# - Mid-term features
# - Spectrogram
# - Zero Crossings
# - Spectral Rolloff
# - MFCC

# %% [markdown]
# ### Import the library

# %%
#!pip install pyAudioAnalysis

# %%
#!pip install pydub

# %%
from pyAudioAnalysis import ShortTermFeatures as aF
from pyAudioAnalysis import audioBasicIO as aIO 
import numpy as np 
import plotly.graph_objects as go 
import plotly
import IPython
from matplotlib import pyplot as plt

# %% [markdown]
# ### Read Audio file

# %%
from pydub import AudioSegment

# 讀取原始音訊（可為 mp3、wav、ogg 等）
audio = AudioSegment.from_file("count.wav")
# 轉換成純淨的 PCM 格式（44.1kHz, 16bit）
audio = audio.set_frame_rate(44100).set_sample_width(2).set_channels(1)
audio.export("count_clean.wav", format="wav")
# Out:
# <_io.BufferedRandom name='count_clean.wav'>

# %%
fs, s = aIO.read_audio_file("count_clean.wav")

# %% [markdown]
# ### Play the audio file

# %%
IPython.display.display(IPython.display.Audio("count_clean.wav"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Duration of the audio file

# %%
duration = len(s) / float(fs)
print(f'duration = {duration} seconds')
# Out:
# duration = 5.855986394557823 seconds

# %% [markdown]
# ### Extract short-term features using a 50msec non-overlapping windows

# %% [markdown]
# ### Extract features
# - Use feature_extraction( )
#     - **signal**:         the input signal samples
#     - **sampling_rate**:  the sampling freq (in Hz)
#     - **window**:         the short-term window size (in samples)
#     - **step**:           the short-term window step (in samples)
#     - **deltas**:         (opt) True/False if delta features are to be computed
# - RETURNS
#     - **features** (numpy.ndarray):        contains features (n_feats x numOfShortTermWindows)
#     - **feature_names** (numpy.ndarray):   contains feature names (n_feats x numOfShortTermWindows)

# %%
win, step = 0.050, 0.050

# %%
[f, fn] = aF.feature_extraction(s, 
                                fs, 
                                int(fs * win), 
                                int(fs * step)
)

# %% [markdown]
# ### How many frames

# %%
print(f'{f.shape[1]} frames')
# Out:
# 117 frames

# %% [markdown]
# ### How many features

# %%
print(f"{f.shape[0]} short-term features")
# Out:
# 68 short-term features

# %% [markdown]
# ### Feature Names

# %%
print('Feature names:')
for i, nam in enumerate(fn):
    print(f'{i}:{nam}')
# Out:
# Feature names:
# 0:zcr
# 1:energy
# 2:energy_entropy
# 3:spectral_centroid
# 4:spectral_spread
# 5:spectral_entropy
# 6:spectral_flux
# 7:spectral_rolloff
# 8:mfcc_1
# 9:mfcc_2
# 10:mfcc_3
# 11:mfcc_4
# 12:mfcc_5
# 13:mfcc_6
# 14:mfcc_7
# 15:mfcc_8
# 16:mfcc_9
# 17:mfcc_10
# 18:mfcc_11
# 19:mfcc_12
# 20:mfcc_13
# 21:chroma_1
# 22:chroma_2
# 23:chroma_3
# 24:chroma_4
# 25:chroma_5
# 26:chroma_6
# 27:chroma_7
# 28:chroma_8
# 29:chroma_9
# 30:chroma_10
# 31:chroma_11
# 32:chroma_12
# 33:chroma_std
# 34:delta zcr
# 35:delta energy
# 36:delta energy_entropy
# 37:delta spectral_centroid
# 38:delta spectral_spread
# 39:delta spectral_entropy
# 40:delta spectral_flux
# 41:delta spectral_rolloff
# 42:delta mfcc_1
# 43:delta mfcc_2
# 44:delta mfcc_3
# 45:delta mfcc_4
# 46:delta mfcc_5
# 47:delta mfcc_6
# 48:delta mfcc_7
# 49:delta mfcc_8
# 50:delta mfcc_9
# 51:delta mfcc_10
# 52:delta mfcc_11
# 53:delta mfcc_12
# 54:delta mfcc_13
# 55:delta chroma_1
# 56:delta chroma_2
# 57:delta chroma_3
# 58:delta chroma_4
# 59:delta chroma_5
# 60:delta chroma_6
# 61:delta chroma_7
# 62:delta chroma_8
# 63:delta chroma_9
# 64:delta chroma_10
# 65:delta chroma_11
# 66:delta chroma_12
# 67:delta chroma_std

# %% [markdown]
# ### Plot Short-term energy

# %% [markdown]
# ### Time

# %%
time = np.arange(0, duration - step, win)

# %%
time
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  , 1.05,
#        1.1 , 1.15, 1.2 , 1.25, 1.3 , 1.35, 1.4 , 1.45, 1.5 , 1.55, 1.6 ,
#        1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 , 1.95, 2.  , 2.05, 2.1 , 2.15,
#        2.2 , 2.25, 2.3 , 2.35, 2.4 , 2.45, 2.5 , 2.55, 2.6 , 2.65, 2.7 ,
#        2.75, 2.8 , 2.85, 2.9 , 2.95, 3.  , 3.05, 3.1 , 3.15, 3.2 , 3.25,
#        3.3 , 3.35, 3.4 , 3.45, 3.5 , 3.55, 3.6 , 3.65, 3.7 , 3.75, 3.8 ,
#        3.85, 3.9 , 3.95, 4.  , 4.05, 4.1 , 4.15, 4.2 , 4.25, 4.3 , 4.35,
#        4.4 , 4.45, 4.5 , 4.55, 4.6 , 4.65, 4.7 , 4.75, 4.8 , 4.85, 4.9 ,
#        4.95, 5.  , 5.05, 5.1 , 5.15, 5.2 , 5.25, 5.3 , 5.35, 5.4 , 5.45,
#        5.5 , 5.55, 5.6 , 5.65, 5.7 , 5.75, 5.8 ])

# %% [markdown]
# # Energy

# %%
energy = f[fn.index('energy'), :]

# %%
energy
# Out:
# array([1.07890613e-06, 1.74289954e-06, 1.70362763e-06, 2.23063305e-02,
#        1.84772092e-01, 2.27772893e-01, 1.65490212e-01, 2.44719804e-02,
#        1.31653876e-02, 2.34875887e-03, 6.69033156e-05, 2.46190719e-05,
#        1.17227964e-05, 3.19135308e-06, 2.61021233e-03, 1.40602654e-01,
#        2.32214304e-01, 3.61335734e-02, 4.22172164e-03, 4.19306762e-04,
#        2.29072782e-05, 2.56396177e-05, 2.31056053e-05, 3.79400373e-06,
#        1.68078744e-05, 9.12907732e-03, 8.47620630e-02, 1.17265996e-01,
#        1.61217348e-01, 4.83547026e-02, 1.71703907e-03, 3.96354953e-05,
#        2.33361478e-05, 1.11376197e-05, 1.69339079e-06, 3.89459855e-05,
#        1.12239655e-03, 1.20969338e-01, 2.31741744e-01, 1.71204475e-01,
#        4.26655051e-02, 6.16388447e-02, 5.47701975e-03, 4.02560919e-04,
#        1.60292584e-05, 3.39897110e-05, 2.92423461e-05, 1.60676941e-05,
#        6.35907552e-05, 6.07606275e-02, 1.80708282e-01, 1.42489019e-01,
#        7.68767340e-02, 1.99111419e-02, 4.74860607e-04, 3.66982512e-04,
#        4.06131368e-05, 2.20704994e-05, 2.61179330e-05, 2.45762322e-06,
#        1.82473884e-04, 1.81628087e-02, 3.51703509e-02, 2.72481823e-02,
#        1.48740646e-01, 5.65769199e-02, 1.75426352e-04, 1.00853080e-02,
#        2.85381829e-02, 2.77247278e-04, 2.41739198e-06, 7.07821055e-04,
#        2.01181438e-02, 1.76107163e-02, 1.71633618e-01, 1.44274465e-01,
#        2.16896849e-02, 4.14590028e-02, 1.79769394e-02, 1.33642690e-02,
#        1.05564441e-03, 6.63856084e-05, 2.88964964e-05, 1.48723059e-05,
#        7.57804735e-06, 9.74950294e-02, 1.44815849e-01, 9.21489834e-02,
#        1.75722080e-02, 8.88163871e-03, 2.48226771e-04, 2.29947142e-04,
#        2.77658930e-05, 1.56368403e-05, 1.20211781e-05, 1.82699908e-03,
#        2.13727412e-02, 6.22677627e-02, 1.27390879e-01, 1.24455924e-01,
#        8.76036089e-02, 3.26263890e-02, 1.51591999e-02, 3.01151928e-03,
#        7.67822564e-05, 2.35515398e-05, 1.92493943e-05, 2.06738241e-06,
#        1.50286832e-03, 7.52102834e-02, 1.04894483e-01, 4.29759275e-02,
#        1.69834781e-02, 9.49910920e-03, 7.00077144e-04, 3.90858992e-05,
#        2.09917257e-05])

# %% [markdown]
# ### Plot Time Vs Energy

# %%
plt.figure(figsize=(10,10))
plt.xlabel("Time (in seconds)")
plt.ylabel("Energy")
plt.plot(time, energy)

# %% [markdown]
# # Spectral Centroid
# ### Spectral centroid -- centre of mass -- weighted mean of the frequencies present in the sound

# %%
spectral_centroid = f[fn.index('spectral_centroid'), :]

# %% [markdown]
# ### Plot Time Vs Spectral Centroid

# %%
plt.figure(figsize=(10,10))
plt.xlabel("Time (in seconds)")
plt.ylabel("Spectral Centroid")
plt.plot(time, spectral_centroid)

# %% [markdown]
# ### Use librosa library

# %%
import sklearn
import librosa
import librosa.display

# %% [markdown]
# ### Read the audio file

# %%
audio_path = 'count_clean.wav'
x , sr = librosa.load(audio_path)

# %% [markdown]
# ### Compute Spectral Centroids

# %%
spectral_centroids = librosa.feature.spectral_centroid(y=x, sr=sr)[0]

print(spectral_centroids.shape)
# Out:
# (253,)

# %% [markdown]
# ### Computing the time variable for visualization

# %%
frames = range(len(spectral_centroids))
t = librosa.frames_to_time(frames)

# %% [markdown]
# ### Normalising the spectral centroid for visualisation

# %%
def normalize(x, axis=0):
    return sklearn.preprocessing.minmax_scale(x, axis=axis)

# %% [markdown]
# ### Plotting the Spectral Centroid along the waveform

# %%
plt.figure(figsize=(10, 10))
librosa.display.waveshow(x, sr=sr, alpha=0.4)
plt.plot(t, normalize(spectral_centroids), color='r')

# %% [markdown]
# 🔵 藍色的波形圖（waveform）
# 顯示的是聲音的原始波形（振幅 vs. 時間）
#
# X軸：時間（秒）
#
# Y軸：音訊振幅（範圍從 -1 到 1）
#
# 你可以把它想成是聲音在時間上的「形狀」
# 大小聲、節奏等都能從這裡看到一些端倪
#
# 🔴 紅色的線條：Spectral Centroid（頻譜質心）
# 這是每一個時間點聲音的「頻率重心」
#
# 可以理解成該時間點聲音的明亮程度（brightness）
#
# 高頻越多 → 質心偏高 → 聽起來尖銳、明亮
#
# 低頻越多 → 質心偏低 → 聽起來沉穩、低沉
#
# 紅線的高低變化顯示頻譜的能量重心如何隨時間移動

# %% [markdown]
# # Mid-term features

# %% [markdown]
# ### Steps
# - Import the library
# - Extract mid_features

# %% [markdown]
# ### Import the library

# %%
from pyAudioAnalysis import MidTermFeatures as aF

# %% [markdown]
# ### Extract features
# - Use mid_feature_extraction( )
#     - signal
#     - sampling_rate
#     - mid_window
#     - mid_step
#     - short_window
#     - short_step

# %%
mt, st, mt_n = aF.mid_feature_extraction(s, 
                                         fs, 
                                         1 * fs, 
                                         1 * fs, 
                                         0.05 * fs, 
                                         0.05 * fs
)

# %% [markdown]
# ### Duration, Short-term features, Segment features

# %%
print(f'signal duration {len(s)/fs} seconds')
print(f'{st.shape[1]} {st.shape[0]}-D short-term feature vectors extracted')
print(f'{mt.shape[1]} {mt.shape[0]}-D segment feature statistic vectors extracted')
# Out:
# signal duration 5.855986394557823 seconds
# 117 68-D short-term feature vectors extracted
# 6 136-D segment feature statistic vectors extracted

# %% [markdown]
# ### Mid-term feature names

# %%
print('mid-term feature names')
for i, mi in enumerate(mt_n):
    print(f'{i}:{mi}')
# Out:
# mid-term feature names
# 0:zcr_mean
# 1:energy_mean
# 2:energy_entropy_mean
# 3:spectral_centroid_mean
# 4:spectral_spread_mean
# 5:spectral_entropy_mean
# 6:spectral_flux_mean
# 7:spectral_rolloff_mean
# 8:mfcc_1_mean
# 9:mfcc_2_mean
# 10:mfcc_3_mean
# 11:mfcc_4_mean
# 12:mfcc_5_mean
# 13:mfcc_6_mean
# 14:mfcc_7_mean
# 15:mfcc_8_mean
# 16:mfcc_9_mean
# 17:mfcc_10_mean
# 18:mfcc_11_mean
# 19:mfcc_12_mean
# 20:mfcc_13_mean
# 21:chroma_1_mean
# 22:chroma_2_mean
# 23:chroma_3_mean
# 24:chroma_4_mean
# 25:chroma_5_mean
# 26:chroma_6_mean
# 27:chroma_7_mean
# 28:chroma_8_mean
# 29:chroma_9_mean
# 30:chroma_10_mean
# 31:chroma_11_mean
# 32:chroma_12_mean
# 33:chroma_std_mean
# 34:delta zcr_mean
# 35:delta energy_mean
# 36:delta energy_entropy_mean
# 37:delta spectral_centroid_mean
# 38:delta spectral_spread_mean
# 39:delta spectral_entropy_mean
# 40:delta spectral_flux_mean
# 41:delta spectral_rolloff_mean
# 42:delta mfcc_1_mean
# 43:delta mfcc_2_mean
# 44:delta mfcc_3_mean
# 45:delta mfcc_4_mean
# 46:delta mfcc_5_mean
# 47:delta mfcc_6_mean
# 48:delta mfcc_7_mean
# 49:delta mfcc_8_mean
# 50:delta mfcc_9_mean
# 51:delta mfcc_10_mean
# 52:delta mfcc_11_mean
# 53:delta mfcc_12_mean
# 54:delta mfcc_13_mean
# 55:delta chroma_1_mean
# 56:delta chroma_2_mean
# 57:delta chroma_3_mean
# 58:delta chroma_4_mean
# 59:delta chroma_5_mean
# 60:delta chroma_6_mean
# 61:delta chroma_7_mean
# 62:delta chroma_8_mean
# 63:delta chroma_9_mean
# 64:delta chroma_10_mean
# 65:delta chroma_11_mean
# 66:delta chroma_12_mean
# 67:delta chroma_std_mean
# 68:zcr_std
# 69:energy_std
# 70:energy_entropy_std
# 71:spectral_centroid_std
# 72:spectral_spread_std
# 73:spectral_entropy_std
# 74:spectral_flux_std
# 75:spectral_rolloff_std
# 76:mfcc_1_std
# 77:mfcc_2_std
# 78:mfcc_3_std
# 79:mfcc_4_std
# 80:mfcc_5_std
# 81:mfcc_6_std
# 82:mfcc_7_std
# 83:mfcc_8_std
# 84:mfcc_9_std
# 85:mfcc_10_std
# 86:mfcc_11_std
# 87:mfcc_12_std
# 88:mfcc_13_std
# 89:chroma_1_std
# 90:chroma_2_std
# 91:chroma_3_std
# 92:chroma_4_std
# 93:chroma_5_std
# 94:chroma_6_std
# 95:chroma_7_std
# 96:chroma_8_std
# 97:chroma_9_std
# 98:chroma_10_std
# 99:chroma_11_std
# 100:chroma_12_std
# 101:chroma_std_std
# 102:delta zcr_std
# 103:delta energy_std
# 104:delta energy_entropy_std
# 105:delta spectral_centroid_std
# 106:delta spectral_spread_std
# 107:delta spectral_entropy_std
# 108:delta spectral_flux_std
# 109:delta spectral_rolloff_std
# 110:delta mfcc_1_std
# 111:delta mfcc_2_std
# 112:delta mfcc_3_std
# 113:delta mfcc_4_std
# 114:delta mfcc_5_std
# 115:delta mfcc_6_std
# 116:delta mfcc_7_std
# 117:delta mfcc_8_std
# 118:delta mfcc_9_std
# 119:delta mfcc_10_std
# 120:delta mfcc_11_std
# 121:delta mfcc_12_std
# 122:delta mfcc_13_std
# 123:delta chroma_1_std
# 124:delta chroma_2_std
# 125:delta chroma_3_std
# 126:delta chroma_4_std
# 127:delta chroma_5_std
# 128:delta chroma_6_std
# 129:delta chroma_7_std
# 130:delta chroma_8_std
# 131:delta chroma_9_std
# 132:delta chroma_10_std
# 133:delta chroma_11_std
# 134:delta chroma_12_std
# 135:delta chroma_std_std

# %% [markdown]
# # Spectrogram

# %% [markdown]
# ### Steps
# - Import the **librosa** library
# - Load the audio file
# - Compute Frequencies using FT
# - Compute Amplitude
# - Plot Frequencies Vs Amplitude as Spectrogram

# %% [markdown]
# ### Import the library

# %%
import librosa
import librosa.display
from matplotlib import pyplot as plt

# %% [markdown]
# ### Load the audio file

# %%
audio_path = 'count.wav'
x , sr = librosa.load(audio_path)

# %% [markdown]
# #### Sampling rate

# %%
print(sr)
# Out:
# 22050

# %% [markdown]
# ### Compute Frequencies

# %%
X = librosa.stft(x)
X.shape
# Out:
# (1025, 253)

# %% [markdown]
# ### Compute Amplitude

# %%
Xdb = librosa.amplitude_to_db(abs(X))
Xdb.shape
# Out:
# (1025, 253)

# %% [markdown]
# ### Display Spectrogram

# %%
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz') 
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %% [markdown]
# # Zero Crossings

# %% [markdown]
# ### Steps
# - Import the library
# - Read the Audio file
# - Compute Zero Crossings
# - Plot zero crossings

# %% [markdown]
# ### Import the library

# %%
import librosa
import librosa.display

# %% [markdown]
# ### Read the audio file

# %%
audio_path = 'count.wav'
x , sr = librosa.load(audio_path)

# %% [markdown]
# ### Plot the signal

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %% [markdown]
# ### Compute Zero Crossings

# %%
zero_crossings = librosa.zero_crossings(x, pad=False)

# %%
zero_crossings
# Out:
# array([False, False,  True, ..., False, False, False])

# %%
sum(zero_crossings)
# Out:
# 15198

# %% [markdown]
# # Spectral Rolloff

# %%
spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)[0]

# %% [markdown]
# ### Plot Spectral Rolloff

# %%
plt.figure(figsize=(10, 10))
librosa.display.waveplot(x, sr=sr, alpha=0.4)
plt.plot(t, normalize(spectral_rolloff), color='r')

# %% [markdown]
# ### Spectral Centroids

# %%
plt.figure(figsize=(10, 10))
librosa.display.waveplot(x, sr=sr, alpha=0.4)
plt.plot(t, normalize(spectral_rolloff), color='r')
plt.plot(t, normalize(spectral_centroids), color='g')

# %% [markdown]
# # MFCC

# %% [markdown]
# ### Compute MFCC

# %%
mfccs = librosa.feature.mfcc(x, sr=sr)

# %%
print(mfccs.shape)
# Out:
# (20, 253)

# %% [markdown]
# ### Plot MFCC

# %%
plt.figure(figsize=(10, 10))
librosa.display.specshow(mfccs, sr=sr, x_axis='time')

# %% [markdown]
# # Chromagram

# %% [markdown]
# ### Compute Chromagram

# %%
chroma = librosa.feature.chroma_stft(x, sr=sr)

# %% [markdown]
# ### Plot Chromagram

# %%
plt.figure(figsize=(14, 5))
librosa.display.specshow(chroma, sr=sr, x_axis='time')
plt.colorbar()
