# %% [markdown]
# # Essay Writer Application: Text Generation
# ### NGram Language Model Text Generation

# %%
from nltk.corpus import reuters
from nltk import bigrams, trigrams
from collections import Counter, defaultdict

# %% [markdown]
# ### Create a placeholder for model

# %%
model = defaultdict(lambda: defaultdict(lambda: 0))
model
# Out:
# defaultdict(<function __main__.<lambda>()>, {})

# %%
This is good time

# %%
bigrams = [(This, is), (is, good), (good, time)]

# %% [markdown]
# ### Count frequency of co-occurance

# %%
for sentence in reuters.sents():
    for w1, w2, w3 in trigrams(sentence, pad_right=True, pad_left=True):
        model[(w1, w2)][w3] += 1
model
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {(None,
#               None): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ASIAN': 4,
#                           'They': 446,
#                           'But': 1054,
#                           'The': 8839,
#                           'Unofficial': 1,
#                           '"': 3589,
#                           'In': 1380,
#                           'Threat': 2,
#                           'Taiwan': 38,
#                           'Retaliation': 3,
#                           'A': 764,
#                           'Last': 202,
#                           'Much': 8,
#                           'He': 1586,
#                           'Meanwhile': 41,
#                           'Japan': 111,
#                           'Deputy': 8,
#                           'CHINA': 50,
#                           'It': 1768,
#                           'JAPAN': 164,
#                           'MITI': 12,
# ...

# %% [markdown]
# ### Transform the counts to probabilities

# %%
for w1_w2 in model:
    total_count = float(sum(model[w1_w2].values()))
    for w3 in model[w1_w2]:
        model[w1_w2][w3] /= total_count
model
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {(None,
#               None): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ASIAN': 7.31047591198187e-05,
#                           'They': 0.008151180641859785,
#                           'But': 0.019263104028072228,
#                           'The': 0.16154324146501936,
#                           'Unofficial': 1.8276189779954676e-05,
#                           '"': 0.06559324512025733,
#                           'In': 0.02522114189633745,
#                           'Threat': 3.655237955990935e-05,
#                           'Taiwan': 0.0006944952116382777,
#                           'Retaliation': 5.482856933986402e-05,
#                           'A': 0.013963008991885371,
#                           'Last': 0.0036917903355508444,
#                           'Much': 0.0001462095182396374,
#                           'He': 0.028986036991008116,
# ...

# %% [markdown]
# ### Predict the next word

# %%
dict(model['today', 'the'])
# Out:
# {'public': 0.05555555555555555,
#  'European': 0.05555555555555555,
#  'Bank': 0.05555555555555555,
#  'price': 0.1111111111111111,
#  'emirate': 0.05555555555555555,
#  'overseas': 0.05555555555555555,
#  'newspaper': 0.05555555555555555,
#  'company': 0.16666666666666666,
#  'Turkish': 0.05555555555555555,
#  'increase': 0.05555555555555555,
#  'options': 0.05555555555555555,
#  'Higher': 0.05555555555555555,
#  'pound': 0.05555555555555555,
#  'Italian': 0.05555555555555555,
#  'time': 0.05555555555555555}

# %%
dict(model['the', 'company'])
# Out:
# {"'": 0.2452344152498712,
#  'is': 0.02009273570324575,
#  'was': 0.0190623390005152,
#  'said': 0.21947449768160743,
#  'lost': 0.0030911901081916537,
#  'reported': 0.018031942297784646,
#  'to': 0.03554868624420402,
#  'has': 0.02266872746007213,
#  'and': 0.01648634724368882,
#  '.': 0.08294693456980938,
#  'as': 0.004121586810922205,
#  'of': 0.0015455950540958269,
#  ',': 0.04070066975785677,
#  'earned': 0.0072127769191138585,
#  'will': 0.019577537351880475,
#  'intends': 0.002575991756826378,
#  'into': 0.0015455950540958269,
#  'also': 0.0020607934054611026,
#  ',"': 0.005667181865018032,
#  'told': 0.0015455950540958269,
#  'were': 0.0010303967027305513,
#  'in': 0.006697578567748583,
#  '"': 0.0015455950540958269,
#  'had': 0.01751674394641937,
#  'realised': 0.0005151983513652757,
#  'by': 0.005151983513652756,
#  'recovered': 0.0005151983513652757,
#  'at': 0.005667181865018032,
#  'hopes': 0.0015455950540958269,
#  'anticipates': 0.0005151983513652757,
# ...

# %%
dict(model['company', 'said'])
# Out:
# {'it': 0.22103533278553822,
#  'in': 0.03204601479046836,
#  '.': 0.2580115036976171,
#  '1986': 0.0008216926869350862,
#  'the': 0.20706655710764174,
#  'research': 0.0008216926869350862,
#  'demand': 0.0008216926869350862,
#  'revenue': 0.0008216926869350862,
#  'backlog': 0.0008216926869350862,
#  'shareholders': 0.00657354149548069,
#  'that': 0.021364009860312245,
#  'its': 0.04683648315529992,
#  'guilder': 0.0008216926869350862,
#  'results': 0.0016433853738701725,
#  'as': 0.0016433853738701725,
#  'Lane': 0.0008216926869350862,
#  'Hanson': 0.0008216926869350862,
#  'Phoenix': 0.0008216926869350862,
#  'Detroit': 0.0008216926869350862,
#  'extreme': 0.0016433853738701725,
#  'Sealy': 0.0016433853738701725,
#  'a': 0.014790468364831553,
#  'First': 0.0024650780608052587,
#  'Modern': 0.0008216926869350862,
#  'sales': 0.0016433853738701725,
#  'MCC': 0.0008216926869350862,
#  'under': 0.0024650780608052587,
#  'dividends': 0.0008216926869350862,
# ...

# %% [markdown]
# ### Script to generate the above predictions of next words

# %%
import random

# starting words
text = ["today", "the"]
sentence_finished = False
 
while not sentence_finished:
  # select a random probability threshold  
  r = random.random()
  accumulator = .0

  for word in model[tuple(text[-2:])].keys():
      accumulator += model[tuple(text[-2:])][word]
      # select words that are above the probability threshold
      if accumulator >= r:
          text.append(word)
          break

  if text[-2:] == [None, None]:
      sentence_finished = True
 
print (' '.join([t for t in text if t]))
# Out:
# today the newspaper said Harrington may propose a permanent scheme , the Bank of Finland said it has entered into a new company will operate as a result , riyal deposits to cover the sale is part of Nigeria ' s & lt ; East Rand Proprietary Mines Ltd > yielding an extraordinary recovery of deferred charges amounting to some 412 mln guilders this week .

# %%
P (word | firstword, secondword) =

# %% [markdown]
# ### Text Generator method

# %%
def text_generator(text):
    sentence_finished = False

    while not sentence_finished:
      # select a random probability threshold  
      r = random.random()
      accumulator = .0

      for word in model[tuple(text[-2:])].keys():
          accumulator += model[tuple(text[-2:])][word]
          # select words that are above the probability threshold
          if accumulator >= r:
              text.append(word)
              break

      if text[-2:] == [None, None]:
          sentence_finished = True

    print(' '.join([t for t in text if t]))
    return 0

# %%
text_generator(['today', 'the'])
# Out:
# today the newspaper the investment by Nippon Kokan , are set at 93 , Bass Strait crude are no plans to meet with Jorge Cardenas are not eligible to vote on a loss of 91 - day special advances at 5 . 74 billion dlrs from 1 . 015 of a Japanese firm , said he thought it unlikely that the economy should achieve the 1987 budget deficit or squeezing investment , banking sources said earlier this week .
# 0

# %%
text_generator(['today', 'the'])
# Out:
# today the time to considering making wood products to make a contribution to earnings of 72 mln last month .
# 0

# %%
text_generator(['today', 'the'])
# Out:
# today the emirate ' s assets for an initial investment of more than 22 mln stg assistance during the year prior include pre - pay contractual disputes that have appeared in USA Today reported that first half of the future .
# 0

# %%
text_generator(['today', 'the'])
# Out:
# today the time being because of higher yielding varieties , and 570 , 000 dlrs or 78 cts vs loss 4 . 5 PCT IN FEBRUARY Year - ago results restated , though ground has to do so without an agreement of multilateral and bilateral aid donors have committed ourselves to reestablishing the normal level of 34 . 9 mln Nine months Shr loss 4 , 410 dlrs , up from 850 mln dlr secured line of athletic and leisure footwear , clothing and footwear .
# 0

# %%
text_generator(['today', 'the'])
# Out:
# today the company said it agreed to sell its Cleveland chemical plant , situated in North America had fiscal year end there had been targeted as yet , he said .
# 0

# %%
text_generator(['today', 'the'])
# Out:
# today the public finances , had performed well both technically and economically viable ."
# 0

# %%
text_generator(['today', 'the'])
# Out:
# today the time may not be named chairman in 1981 , fell by a seasonally adjusted figures show .
# 0

# %%
text_generator(['today', 'the'])
# Out:
# today the Bank to be done to reduce sugar price support levels for the year ended October 31 , up 4 . 21 dlrs Net 5 , 940 shares of Circle Express Inc said its shareholders will receive 5 . 1 mln dlrs as of March were 2 . 25 dlr convertible preferred stock .
# 0
