# %% [markdown]
# # Speech Recognition  - Speech-To-Text
# ## This notebook outlines the techniques involved in Speech to text conversion

# %% [markdown]
# Speech Recognition is a system that **translates** the language being spoken into digitized text format
#
# ### Features
#
# **Streaming speech to text in real-time**: the API is capable of processing real-time audio signals from the device microphone or take an audio file as input and convert it into text
#
# **Different models based on the domain**: you can choose from different trained models depending on the requirements of the project. For example, for converting audio from a telephone, the enhanced **phone call model** can be used
#
# **Adaptation**: you can customize the API to understand
# - rare words
# - currency
# - numbers
# - medical lingo

# %% [markdown]
# ### Steps
# - 1. Install the library
# - 2. Import the library
# - 3. Create Speech Recognizer object
# - 4. Listen to audio source
#     - microphone
#     - audio file
# - 5. Convert speech into text

# %% [markdown]
# ### Install the library

# %%
#pip install SpeechRecognition

# %% [markdown]
# ### Import the library

# %%
import speech_recognition as sr

# %% [markdown]
# ### Create Speech Recognizer object

# %%
recognizer = sr.Recognizer()

# %%
recognizer

# %% [markdown]
# ### Listen to the microphone

# %%
with sr.Microphone() as source:
    print("Please speak up now")
    listening = recognizer.listen(source, timeout=30000)
    print(recognizer.recognize_google(listening))
# Out:
# Please speak up now
# hi my name is Smosh and I'm your professor at George Brown College please welcome to all the courses here in AI development Solutions program this course is on speech-to-text conversion have a happy course and I'll see you in the next course

# %% [markdown]
# ### Listen to the audio source - audio file

# %% [markdown]
# ### Audio file - Some audio file of your choice

# %%
import IPython

# %%
IPython.display.display(IPython.display.Audio('Speaker_Diarization_Example.wav'))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#!pip install pydub

# %%
from pydub import AudioSegment

sound = AudioSegment.from_file("Speaker_Diarization_Example.wav")
sound = sound.set_channels(1).set_frame_rate(16000).set_sample_width(2)
sound.export("output.wav", format="wav")
# Out:
# <_io.BufferedRandom name='output.wav'>

# %%
import speech_recognition as sr
recognition = sr.Recognizer()
with sr.AudioFile('output.wav') as inputs:
    file_audio = recognition.listen(inputs)
    try:
        convert_text = recognition.recognize_google(file_audio)
        print('Analysing...')
        print(convert_text)
    except sr.UnknownValueError:
         print('Sorry, Could not understand this audio...')
# Out:
# Analysing...
# we see it in the

# %% [markdown]
# ### Try with other audio file samples

# %%
IPython.display.display(IPython.display.Audio('Speaker_Diarization_Example2.wav'))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
r = sr.Recognizer()
with sr.AudioFile('Speaker_Diarization_Example2.wav') as source:
    #reads the audio file. Here we use record instead of
    #listen
    audio = r.record(source, duration=41) 
    try:
        print("The audio file contains: " + r.recognize_google(audio))
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
# Out:
# The audio file contains: all I was receiving it in the United Kingdom and I was told it I didn't need it on here because

# %%
IPython.display.display(IPython.display.Audio('political_diarization_cluster_3.wav'))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
r = sr.Recognizer()
with sr.AudioFile('political_diarization_cluster_3.wav') as source:
    #reads the audio file. Here we use record instead of
    #listen
    audio = r.record(source) 
    try:
        print("The audio file contains: " + r.recognize_google(audio))
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand this audio")
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
# Out:
# The audio file contains: with the whole post office
