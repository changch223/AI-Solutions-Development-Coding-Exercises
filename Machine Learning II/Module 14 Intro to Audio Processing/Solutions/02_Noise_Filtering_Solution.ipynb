# %% [markdown]
# # Noise filtering
# ## This notebook outlines the concepts behind filtering noise in audio signal

# %% [markdown]
# ### Steps
# - Create a combined noisy signal
#     - Create a Sine wave (Original signal)
#     - Create a noise signal
# - Compute frequencies
# - Filter the frequencies
# - Recover the signal from the filtered frequencies
# - Plot the original (recovered / noise filtered) signal Vs Noisy signal

# %% [markdown]
# ### Import the libraries

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Set the parameters for the signals
# - signal frequency
# - noise frequency
# - number of samples
# - sampling rate

# %%
frequency = 1000
noisy_freq = 50
num_samples = 48000
sampling_rate = 48000.0

# %% [markdown]
# ### Create the original signal

# %%
sine_wave = [np.sin(2 * np.pi * frequency * x1 / sampling_rate) for x1 in range(num_samples)]

# %% [markdown]
# ### Create the noise

# %%
sine_noise = [np.sin(2 * np.pi * noisy_freq * x1/  sampling_rate) for x1 in range(num_samples)]

# %% [markdown]
# ### Convert them to numpy arrays

# %%
sine_wave = np.array(sine_wave)
sine_noise = np.array(sine_noise)

# %% [markdown]
# ### Create the combined Noisy Signal

# %%
combined_signal = sine_wave + sine_noise

# %% [markdown]
# ### Plot the Original and Noisy signal

# %%
plt.figure(figsize=(10,10))
plt.subplot(3,1,1)
plt.title("Original sine wave")
 
plt.subplots_adjust(hspace=.5)
plt.plot(sine_wave[:500])
 
plt.subplot(3,1,2)
plt.title("Noisy wave")
plt.plot(sine_noise[:4000])
 
plt.subplot(3,1,3)
plt.title("Original + Noise")
plt.plot(combined_signal[:3000])
 
plt.show()

# %% [markdown]
# ### Compute frequencies

# %%
data_fft = np.fft.fft(combined_signal)

# %%
freq = (np.abs(data_fft[:len(data_fft)]))

# %% [markdown]
# ### Filtered frequency

# %%
filtered_freq = [f if (950 < index < 1050 and f > 1) else 0 for index, f in enumerate(freq)]

# %% [markdown]
# ### Plot Frequecies of Original Vs Filtered Signal

# %%
plt.figure(figsize=(10, 10))
plt.subplot(2,1,1)
plt.plot(freq)
plt.title("Before filtering: Will have main signal (1000Hz) + noise frequency (50Hz)")
plt.xlim(0,1200)
plt.ylim(0, 25000)

plt.subplot(2,1,2)
plt.plot(filtered_freq) 
plt.title("After filtering: Main signal only (1000Hz)")
plt.xlim(0,1200)
plt.ylim(0, 25000)

plt.show()
 
plt.close()

# %% [markdown]
# ### Recovered Signal
# - Use Inverse Fourier Transform

# %%
recovered_signal = np.fft.ifft(filtered_freq)

# %% [markdown]
# ### Plot Original Vs Noisy Vs Recovered Signal

# %%
plt.figure(figsize=(10, 10))
plt.subplot(3,1,1)
plt.title("Original sine wave")

plt.subplots_adjust(hspace=.5)
plt.plot(sine_wave[:500])
 
plt.subplot(3,1,2)
plt.title("Noisy wave")
plt.plot(combined_signal[:4000])
 
plt.subplot(3,1,3)
plt.title("Sine wave after clean up")
plt.plot((recovered_signal[:500]))
 
plt.show()
# Out:
# C:\Users\wayne\anaconda3\envs\GBC_Task\lib\site-packages\matplotlib\cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# C:\Users\wayne\anaconda3\envs\GBC_Task\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
