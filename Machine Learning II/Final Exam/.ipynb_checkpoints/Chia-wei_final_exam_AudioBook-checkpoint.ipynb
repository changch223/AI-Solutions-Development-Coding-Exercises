# %% [markdown]
# # Create an Audiobook from a PDF
# ## This task tests your ability to apply Text to Speech conversion and Extraction of Text from PDF files in the creation of an audiobook from a PDF file

# %% [markdown]
# ### Steps
# - Extract text from PDF file
# - Clean the text
# - Convert the text into speech
# - Save the speech
# - Play the speech

# %% [markdown]
# ## 1. Extract text from PDF
# - Use PyPDF2

# %% [markdown]
# ### Install the library

# %%
#! pip install PyPDF2

# %% [markdown]
# ### Import the library

# %%
import PyPDF2

# %% [markdown]
# ### Extract the text

# %%
with open("pdf.pdf", "rb") as file:
    reader = PyPDF2.PdfReader(file)
    page = reader.pages[0]
    text = page.extract_text()

# %% [markdown]
# ### Print the extracted text

# %%
print(text)
# Out:
# Common NLP Tasks
# The following is a list of some of the most commonly researched tasks in natural
# language processing. Some of these tasks have direct real-world applications, while
# others more commonly serve as subtasks that are used to aid in solving larger tasks.
# Though natural language processing tasks are closely intertwined, they can be
# subdivided into categories for convenience. A coarse division is given below.
# Text and speech processing
# Optical character recognition (OCR)
# Given an image representing printed text, determine the corresponding text.

# %% [markdown]
# ## 2. Convert the Text into Speech
# - Use **pyttsx3** OR **gTTS**

# %% [markdown]
# ### Install the library

# %%
# !pip install pyttsx3

# %% [markdown]
# ### Import the library

# %%
import os
from gtts import gTTS

# %% [markdown]
# ### Initialize a Speaker object

# %%
language = 'en'

# %%
speech = gTTS(text = text, lang = language, slow = False)

# %% [markdown]
# ### Convert the text

# %%
speech.save('Text into Speech.wav')

# %% [markdown]
# ### Save the audio

# %%
import IPython
IPython.display.display(IPython.display.Audio('Text into Speech.wav'))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
