# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# Load the data
train_data = pd.read_csv('DailyDelhiClimateTest.csv')
test_data = pd.read_csv('DailyDelhiClimateTrain.csv')

# Combine train and test data for preprocessing
all_data = pd.concat([train_data, test_data], axis=0)

# Convert date to datetime
all_data['date'] = pd.to_datetime(all_data['date'])

# Sort data by date
all_data = all_data.sort_values('date')

# Select features for the model
features = ['meantemp', 'humidity', 'wind_speed', 'meanpressure']

# Normalize the features
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(all_data[features])

# Split back into train and test
train_data = scaled_data[:len(train_data)]
test_data = scaled_data[len(train_data):]

# Define the autoencoder architecture
input_dim = len(features)
encoding_dim = 2  # Reduce to 2 dimensions

# Encoder
input_layer = Input(shape=(input_dim,))
encoded = Dense(8, activation='relu')(input_layer)
encoded = Dense(encoding_dim, activation='relu')(encoded)

# Decoder
decoded = Dense(8, activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

# Autoencoder model
autoencoder = Model(input_layer, decoded)
encoder = Model(input_layer, encoded)

# Compile the model
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# Train the autoencoder
history = autoencoder.fit(train_data, train_data,
                          epochs=100,
                          batch_size=32,
                          shuffle=True,
                          validation_data=(test_data, test_data))

# Plot training history
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Encode the data
encoded_train = encoder.predict(train_data)
encoded_test = encoder.predict(test_data)

# Visualize the encoded data
plt.figure(figsize=(10, 8))
plt.scatter(encoded_train[:, 0], encoded_train[:, 1], alpha=0.5, label='Train')
plt.scatter(encoded_test[:, 0], encoded_test[:, 1], alpha=0.5, label='Test')
plt.title('Encoded Climate Data')
plt.xlabel('Encoded Dimension 1')
plt.ylabel('Encoded Dimension 2')
plt.legend()
plt.show()

# Reconstruct the data
reconstructed_train = autoencoder.predict(train_data)
reconstructed_test = autoencoder.predict(test_data)

# Calculate reconstruction error
train_mse = np.mean(np.power(train_data - reconstructed_train, 2), axis=1)
test_mse = np.mean(np.power(test_data - reconstructed_test, 2), axis=1)

print(f"Average Train MSE: {np.mean(train_mse):.4f}")
print(f"Average Test MSE: {np.mean(test_mse):.4f}")

# Visualize original vs reconstructed data for a sample feature
feature_index = 0  # Index of the feature to visualize (e.g., meantemp)
original = scaler.inverse_transform(train_data)[:, feature_index]
reconstructed = scaler.inverse_transform(reconstructed_train)[:, feature_index]

plt.figure(figsize=(12, 6))
plt.plot(all_data['date'][:len(train_data)], original, label='Original')
plt.plot(all_data['date'][:len(train_data)], reconstructed, label='Reconstructed')
plt.title(f'Original vs Reconstructed {features[feature_index]}')
plt.xlabel('Date')
plt.ylabel(features[feature_index])
plt.legend()
plt.show()

# Analyze the encoded dimensions
for i in range(encoding_dim):
    plt.figure(figsize=(12, 6))
    plt.scatter(all_data['date'][:len(train_data)], encoded_train[:, i], alpha=0.5)
    plt.title(f'Encoded Dimension {i+1} Over Time')
    plt.xlabel('Date')
    plt.ylabel(f'Encoded Value {i+1}')
    plt.show()

# Correlation analysis
encoded_df = pd.DataFrame(encoded_train, columns=[f'Encoded_{i+1}' for i in range(encoding_dim)])
encoded_df['date'] = all_data['date'][:len(train_data)]
encoded_df = encoded_df.set_index('date')

original_df = all_data[features].iloc[:len(train_data)].set_index(all_data['date'][:len(train_data)])

correlation = pd.concat([original_df, encoded_df], axis=1).corr()

plt.figure(figsize=(12, 10))
plt.imshow(correlation, cmap='coolwarm', aspect='auto')
plt.colorbar()
plt.xticks(range(len(correlation.columns)), correlation.columns, rotation=90)
plt.yticks(range(len(correlation.columns)), correlation.columns)
plt.title('Correlation between Original Features and Encoded Dimensions')
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0847 - val_loss: 0.0884
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0827 - val_loss: 0.0875
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0827 - val_loss: 0.0866
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0827 - val_loss: 0.0855
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0787 - val_loss: 0.0844
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0757 - val_loss: 0.0832
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0761 - val_loss: 0.0819
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0733 - val_loss: 0.0805
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0734 - val_loss: 0.0790
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0710 - val_loss: 0.0775
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0696 - val_loss: 0.0759
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0690 - val_loss: 0.0742
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0644 - val_loss: 0.0726
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0637 - val_loss: 0.0709
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0608 - val_loss: 0.0692
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0591 - val_loss: 0.0676
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0580 - val_loss: 0.0660
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0527 - val_loss: 0.0644
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0524 - val_loss: 0.0628
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0497 - val_loss: 0.0612
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0485 - val_loss: 0.0597
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0456 - val_loss: 0.0581
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0451 - val_loss: 0.0566
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0442 - val_loss: 0.0551
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0423 - val_loss: 0.0536
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0411 - val_loss: 0.0522
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0398 - val_loss: 0.0509
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0384 - val_loss: 0.0496
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0362 - val_loss: 0.0483
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0348 - val_loss: 0.0471
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0337 - val_loss: 0.0459
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0333 - val_loss: 0.0448
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0328 - val_loss: 0.0438
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0310 - val_loss: 0.0428
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0303 - val_loss: 0.0419
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0315 - val_loss: 0.0411
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0285 - val_loss: 0.0403
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0304 - val_loss: 0.0396
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0273 - val_loss: 0.0389
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0283 - val_loss: 0.0383
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0270 - val_loss: 0.0378
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0262 - val_loss: 0.0374
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0241 - val_loss: 0.0370
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0250 - val_loss: 0.0367
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0264 - val_loss: 0.0363
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0264 - val_loss: 0.0360
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0250 - val_loss: 0.0357
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0242 - val_loss: 0.0355
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0237 - val_loss: 0.0353
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0242 - val_loss: 0.0351
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0235 - val_loss: 0.0349
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0234 - val_loss: 0.0347
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0226 - val_loss: 0.0346
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0229 - val_loss: 0.0344
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0223 - val_loss: 0.0343
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0242 - val_loss: 0.0343
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0240 - val_loss: 0.0342
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0223 - val_loss: 0.0343
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0246 - val_loss: 0.0342
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0232 - val_loss: 0.0342
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0226 - val_loss: 0.0341
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0231 - val_loss: 0.0340
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0244 - val_loss: 0.0339
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0242 - val_loss: 0.0338
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0239 - val_loss: 0.0338
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0221 - val_loss: 0.0338
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0235 - val_loss: 0.0338
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0228 - val_loss: 0.0338
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0215 - val_loss: 0.0338
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0228 - val_loss: 0.0338
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0229 - val_loss: 0.0338
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0218 - val_loss: 0.0337
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0212 - val_loss: 0.0336
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0218 - val_loss: 0.0336
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0222 - val_loss: 0.0336
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0216 - val_loss: 0.0336
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0221 - val_loss: 0.0336
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0230 - val_loss: 0.0336
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0232 - val_loss: 0.0335
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0223 - val_loss: 0.0336
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0213 - val_loss: 0.0336
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0251 - val_loss: 0.0335
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0235 - val_loss: 0.0334
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0224 - val_loss: 0.0333
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0220 - val_loss: 0.0333
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0230 - val_loss: 0.0333
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0220 - val_loss: 0.0333
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0220 - val_loss: 0.0334
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0214 - val_loss: 0.0334
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0225 - val_loss: 0.0336
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0222 - val_loss: 0.0336
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0231 - val_loss: 0.0337
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0231 - val_loss: 0.0337
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0217 - val_loss: 0.0338
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0211 - val_loss: 0.0338
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0212 - val_loss: 0.0337
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0220 - val_loss: 0.0336
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0202 - val_loss: 0.0335
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0212 - val_loss: 0.0334
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0227 - val_loss: 0.0334
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Average Train MSE: 0.0220
# Average Test MSE: 0.0334

# %%
# Anomaly Detection Section

print("\n--- Anomaly Detection ---\n")

# Calculate reconstruction error for each data point
reconstruction_error = np.mean(np.power(scaled_data - autoencoder.predict(scaled_data), 2), axis=1)

# Determine threshold for anomalies (e.g., 95th percentile of reconstruction error)
threshold = np.percentile(reconstruction_error, 95)
print(f"Anomaly threshold: {threshold:.4f}")

# Identify anomalies
anomalies = reconstruction_error > threshold

# Add reconstruction error and anomaly flag to the original dataframe
all_data['reconstruction_error'] = reconstruction_error
all_data['is_anomaly'] = anomalies

# Print summary of detected anomalies
print(f"Total anomalies detected: {np.sum(anomalies)}")
print(f"Percentage of anomalies: {np.mean(anomalies)*100:.2f}%")

# Visualize reconstruction error over time
plt.figure(figsize=(15, 6))
plt.plot(all_data['date'], all_data['reconstruction_error'], label='Reconstruction Error')
plt.axhline(y=threshold, color='r', linestyle='--', label='Anomaly Threshold')
plt.scatter(all_data['date'][anomalies], all_data['reconstruction_error'][anomalies],
            color='red', label='Anomalies')
plt.title('Reconstruction Error Over Time with Detected Anomalies')
plt.xlabel('Date')
plt.ylabel('Reconstruction Error')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Analyze anomalies for each feature
for feature in features:
    plt.figure(figsize=(15, 6))
    plt.plot(all_data['date'], all_data[feature], label=feature)
    plt.scatter(all_data['date'][anomalies], all_data[feature][anomalies],
                color='red', label='Anomalies')
    plt.title(f'{feature} Over Time with Detected Anomalies')
    plt.xlabel('Date')
    plt.ylabel(feature)
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# Print top 10 anomalies
print("\nTop 10 Anomalies:")
top_anomalies = all_data[anomalies].sort_values('reconstruction_error', ascending=False).head(10)
print(top_anomalies[['date'] + features + ['reconstruction_error']])

# Analyze seasonal patterns in anomalies
all_data['month'] = all_data['date'].dt.month
monthly_anomaly_rate = all_data.groupby('month')['is_anomaly'].mean()

plt.figure(figsize=(12, 6))
monthly_anomaly_rate.plot(kind='bar')
plt.title('Monthly Anomaly Rate')
plt.xlabel('Month')
plt.ylabel('Percentage of Anomalies')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# Correlation between features and anomaly likelihood
correlation_with_anomaly = all_data[features + ['is_anomaly']].corr()['is_anomaly'].sort_values(ascending=False)
print("\nCorrelation between features and anomaly likelihood:")
print(correlation_with_anomaly)

# Visualize feature distributions for normal vs anomalous data
for feature in features:
    plt.figure(figsize=(12, 6))
    plt.hist(all_data[all_data['is_anomaly'] == False][feature], bins=50, alpha=0.5, label='Normal')
    plt.hist(all_data[all_data['is_anomaly'] == True][feature], bins=50, alpha=0.5, label='Anomaly')
    plt.title(f'Distribution of {feature} for Normal vs Anomalous Data')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# --- Anomaly Detection ---
#
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Anomaly threshold: 0.0888
# Total anomalies detected: 79
# Percentage of anomalies: 5.01%
# Top 10 Anomalies:
#            date   meantemp   humidity  wind_speed  meanpressure  \
# 251  2013-09-09  31.000000  57.500000   42.220000   1007.000000
# 1182 2016-03-28  25.933333  52.800000    6.546667   7679.333333
# 960  2015-08-19  31.250000  61.250000   33.325000   1002.375000
# 856  2015-05-07  35.428571  13.428571   15.342857   1003.571429
# 889  2015-06-09  37.625000  23.875000   18.750000    998.875000
# 1217 2016-05-02  38.000000  18.466667    9.513333   1002.200000
# 630  2014-09-23  31.000000  47.000000   30.685714   1004.285714
# 358  2013-12-25  13.666667  63.166667   34.487500   1020.625000
# 522  2014-06-07  38.500000  22.750000   13.187500    994.000000
# 141  2013-05-22  36.750000  22.125000   17.587500    998.625000
#
#       reconstruction_error
# 251               0.248415
# 1182              0.236210
# 960               0.157010
# 856               0.140116
# 889               0.139950
# 1217              0.136255
# 630               0.134905
# 358               0.134855
# 522               0.133512
# 141               0.132857
# Correlation between features and anomaly likelihood:
# is_anomaly      1.000000
# wind_speed      0.300468
# meantemp        0.299839
# meanpressure    0.098074
# humidity       -0.419579
# Name: is_anomaly, dtype: float64
