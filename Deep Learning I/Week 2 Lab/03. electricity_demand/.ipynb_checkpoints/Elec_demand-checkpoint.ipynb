# %% [markdown]
# # Task: Electricity Demand Prediction

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read Data

# %%
dataset_train = pd.read_csv('Elec_Demand_train.csv')

# %%
training_set = dataset_train.iloc[:, 1:2].values

# %% [markdown]
# ## Data Preprocessing

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
training_set.shape
# Out:
# (2688, 1)

# %% [markdown]
# ### Creating a data structure with 60 timesteps and 1 output

# %%
# Creating a data structure with 60 timesteps and 1 output
x_train = []
y_train = []
for i in range(60, len(training_set)):
    x_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
print(x_train.shape)
# Out:
# (2628, 60, 1)

# %%
print(y_train.shape)
# Out:
# (2628,)

# %%
# Reshaping,
# NOTE: Keras expect data in the form of [batch_size, Time_steps, sequence_length]
#             sometimes refer to as [batch_size, timesteps, units]
#             or in other word  [No_samples, No_datapoints_in_time, No_featuers]

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %% [markdown]
# ## Part 2 - Building the RNN

# %%
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from tensorflow import keras

# %%
# Initialising the RNN
my_regressor = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
my_regressor.add(LSTM(units = 30, return_sequences = True,
                      input_shape = (x_train.shape[1], 1)))
my_regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
#my_regressor.add(LSTM(units = 50, return_sequences = True))
#my_regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
#my_regressor.add(LSTM(units = 50, return_sequences = True))
#my_regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
my_regressor.add(LSTM(units = 30))
my_regressor.add(Dropout(0.2))

# Adding the output layer
my_regressor.add(Dense(units = 1))

# Compiling the RNN
my_regressor.compile(optimizer = 'adam', loss = 'mean_squared_error',
                     metrics = ['accuracy'])
# Out:
# C:\Users\wayne\anaconda3\envs\deeplearning-env\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Fitting the RNN to the Training set
history = my_regressor.fit(x_train, y_train, epochs = 100,
                           batch_size = 32)
# Out:
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 4.4584e-04 - loss: 0.0920
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 4.1146e-05 - loss: 0.0367
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 8.3301e-04 - loss: 0.0149
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 3.8019e-04 - loss: 0.0115
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 1.0930e-04 - loss: 0.0092
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 1.1056e-04 - loss: 0.0076
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 2.0206e-04 - loss: 0.0073
# Epoch 8/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 3.7523e-04 - loss: 0.0071
# Epoch 9/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 6.4819e-04 - loss: 0.0062
# Epoch 10/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 3.9164e-04 - loss: 0.0063
# Epoch 11/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 4.2266e-04 - loss: 0.0060
# Epoch 12/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.0015 - loss: 0.0059
# Epoch 13/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 4.2437e-04 - loss: 0.0056
# Epoch 14/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.0014 - loss: 0.0059
# Epoch 15/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 9.7371e-04 - loss: 0.0053
# Epoch 16/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0013 - loss: 0.0047
# Epoch 17/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0010 - loss: 0.0050
# Epoch 18/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 2.2043e-04 - loss: 0.0055
# Epoch 19/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0015 - loss: 0.0048
# Epoch 20/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.0012 - loss: 0.0045
# Epoch 21/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0010 - loss: 0.0044
# Epoch 22/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 5.8167e-04 - loss: 0.0044
# Epoch 23/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 2.4676e-04 - loss: 0.0043
# Epoch 24/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 5.5993e-04 - loss: 0.0039
# Epoch 25/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 3.3527e-04 - loss: 0.0041
# Epoch 26/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 7.5115e-04 - loss: 0.0039
# Epoch 27/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 5.1869e-04 - loss: 0.0040
# Epoch 28/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 9.7310e-05 - loss: 0.0036
# Epoch 29/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0012 - loss: 0.0036
# Epoch 30/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 3.9030e-04 - loss: 0.0033
# Epoch 31/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 7.8756e-04 - loss: 0.0032
# Epoch 32/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 7.3728e-04 - loss: 0.0035
# Epoch 33/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.0011 - loss: 0.0034
# Epoch 34/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 9.8916e-04 - loss: 0.0030
# Epoch 35/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 9.7685e-04 - loss: 0.0032
# Epoch 36/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 5.9767e-04 - loss: 0.0031
# Epoch 37/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 8.7243e-04 - loss: 0.0029
# Epoch 38/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.0014 - loss: 0.0027
# Epoch 39/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 4.0201e-04 - loss: 0.0024
# Epoch 40/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0016 - loss: 0.0025
# Epoch 41/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 8.7532e-04 - loss: 0.0025
# Epoch 42/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 3.9067e-04 - loss: 0.0024
# Epoch 43/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 7.7853e-04 - loss: 0.0023
# Epoch 44/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 1.3350e-04 - loss: 0.0023
# Epoch 45/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 6.7514e-04 - loss: 0.0022
# Epoch 46/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0011 - loss: 0.0021
# Epoch 47/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 4.2682e-04 - loss: 0.0023
# Epoch 48/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0013 - loss: 0.0023
# Epoch 49/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 5.1349e-04 - loss: 0.0021
# Epoch 50/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 2.5159e-04 - loss: 0.0023
# Epoch 51/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.0014 - loss: 0.0020
# Epoch 52/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 5.7306e-04 - loss: 0.0021
# Epoch 53/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0010 - loss: 0.0021
# Epoch 54/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 4.6377e-04 - loss: 0.0018
# Epoch 55/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 8.0486e-05 - loss: 0.0019
# Epoch 56/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 7.2919e-04 - loss: 0.0019
# Epoch 57/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0011 - loss: 0.0018
# Epoch 58/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 3.9053e-04 - loss: 0.0020
# Epoch 59/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 8.4352e-05 - loss: 0.0018
# Epoch 60/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 8.1631e-04 - loss: 0.0017
# Epoch 61/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 7.2443e-04 - loss: 0.0017
# Epoch 62/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 8.7532e-04 - loss: 0.0016
# Epoch 63/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 2.3757e-04 - loss: 0.0018
# Epoch 64/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0021 - loss: 0.0015
# Epoch 65/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 3.2503e-04 - loss: 0.0018
# Epoch 66/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 2.9417e-04 - loss: 0.0015
# Epoch 67/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 2.5820e-04 - loss: 0.0016
# Epoch 68/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 4.7025e-04 - loss: 0.0015
# Epoch 69/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 1.1000e-04 - loss: 0.0015
# Epoch 70/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 6.9857e-04 - loss: 0.0015
# Epoch 71/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 9.0626e-04 - loss: 0.0015
# Epoch 72/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 4.9937e-04 - loss: 0.0016
# Epoch 73/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 7.3204e-04 - loss: 0.0014
# Epoch 74/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0014 - loss: 0.0014
# Epoch 75/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 2.2621e-04 - loss: 0.0015
# Epoch 76/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 6.2640e-04 - loss: 0.0013
# Epoch 77/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 8.1030e-04 - loss: 0.0015
# Epoch 78/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0025 - loss: 0.0014
# Epoch 79/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 5.4443e-04 - loss: 0.0017
# Epoch 80/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0012 - loss: 0.0015
# Epoch 81/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 5.3010e-04 - loss: 0.0013
# Epoch 82/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 7.5071e-04 - loss: 0.0013
# Epoch 83/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 5.1337e-04 - loss: 0.0013
# Epoch 84/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.0019 - loss: 0.0014
# Epoch 85/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 3.0624e-04 - loss: 0.0013
# Epoch 86/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 3.2603e-04 - loss: 0.0013
# Epoch 87/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 3.1000e-04 - loss: 0.0013
# Epoch 88/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 4.9758e-04 - loss: 0.0012
# Epoch 89/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0017 - loss: 0.0013
# Epoch 90/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 6.9032e-04 - loss: 0.0013
# Epoch 91/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.0017 - loss: 0.0013
# Epoch 92/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 7.2923e-04 - loss: 0.0012
# Epoch 93/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 8.2334e-04 - loss: 0.0011
# Epoch 94/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.0021 - loss: 0.0012
# Epoch 95/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 9.0626e-04 - loss: 0.0013
# Epoch 96/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 6.6804e-04 - loss: 0.0012
# Epoch 97/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 6.7691e-04 - loss: 0.0013
# Epoch 98/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0010 - loss: 0.0011
# Epoch 99/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0015 - loss: 0.0012
# Epoch 100/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 5.9496e-04 - loss: 0.0012

# %%
my_regressor.save('demand.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Part 3 - Making the predictions and visualising the results

# %%
dataset_test = pd.read_csv('Elec_Demand_test.csv')


real_price = dataset_test.iloc[:, 1:2].values

dataset_total = pd.concat((dataset_train['Demand'], dataset_test['Demand']), axis = 0)

inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 60+len(dataset_test)):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_price = my_regressor.predict(X_test)
predicted_price = sc.inverse_transform(predicted_price)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step

# %%
# Visualising the results
plt.plot(real_price, color = 'red', label = 'Real ON Electricity Price')
plt.plot(predicted_price, color = 'blue', label = 'Predicted ON Electricity Price')
plt.title('ON Electricity Price Prediction')
plt.xlabel('Time')
plt.ylabel('ON Electricity Price')
plt.legend()
plt.show()

# %%
# list all the data in history
print(history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss'])
