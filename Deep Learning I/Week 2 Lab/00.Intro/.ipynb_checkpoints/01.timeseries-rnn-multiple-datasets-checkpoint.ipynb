# %% [markdown]
# Temporal Order Preservation
# - Unlike traditional datasets, time series data must be split while preserving the chronological order of observations. This means you cannot randomly shuffle the data before splitting, as the temporal dependencies are crucial for accurate modeling and forecasting.
#
# Forward-Looking Validation
# - Your validation and test sets should always be forward in time relative to your training set.
# - This mimics real-world scenarios where you use historical data to predict future outcomes.
#
# Key Considerations
#
# - Forward-Looking Validation: The validation and test sets come after the training set in time, mimicking real-world forecasting scenarios.
# No Shuffling: Unlike in traditional machine learning, we don't shuffle the data to maintain the time-dependent structure.
#
# - Sufficient History: The training set includes a substantial portion of the data to capture long-term patterns and seasonality.
# Future Performance Estimation: The validation set allows for tuning hyperparameters, while the test set provides an unbiased estimate of the model's performance on future, unseen data.

# %%
import pandas as pd
#import data
shampoo_sales = pd.read_csv('shampoo_sales.csv', parse_dates=['Month'] ,index_col='Month')
# Out:
# C:\Users\wayne\AppData\Local\Temp\ipykernel_35564\98180782.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   shampoo_sales = pd.read_csv('shampoo_sales.csv', parse_dates=['Month'] ,index_col='Month')

# %%
shampoo_sales
# Out:
#        Sales
# Month
# 1-01   266.0
# 1-02   145.9
# 1-03   183.1
# 1-04   119.3
# 1-05   180.3
# 1-06   168.5
# 1-07   231.8
# 1-08   224.5
# 1-09   192.8
# 1-10   122.9
# 1-11   336.5
# 1-12   185.9
# 2-01   194.3
# 2-02   149.5
# 2-03   210.1
# 2-04   273.3
# 2-05   191.4
# 2-06   287.0
# 2-07   226.0
# 2-08   303.6
# 2-09   289.9
# 2-10   421.6
# 2-11   264.5
# 2-12   342.3
# 3-01   339.7
# 3-02   440.4
# 3-03   315.9
# 3-04   439.3
# 3-05   401.3
# 3-06   437.4
# 3-07   575.5
# 3-08   407.6
# 3-09   682.0
# 3-10   475.3
# 3-11   581.3
# 3-12   646.9

# %%
train_size = int(len(shampoo_sales) * 0.7)
val_size = int(len(shampoo_sales) * 0.2)
test_size = len(shampoo_sales) - train_size - val_size

train_data = shampoo_sales[:train_size]
validation_data = shampoo_sales[train_size:train_size + val_size]
test_data = shampoo_sales[train_size + val_size:]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras.optimizers import Adam
from datetime import datetime

def parse(x):
    return datetime.strptime('190'+x, '%Y-%m')

# Load the data
df = pd.read_csv('shampoo_sales.csv', header=0, parse_dates=[0], index_col=0, date_parser=parse).squeeze()

# Convert Series to DataFrame
df = df.to_frame(name='Sales')

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)


# Create sequences for time series prediction
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        # Create input sequence (X) of 'seq_length' time steps
        X.append(data[i:(i + seq_length), 0])
        # Create target value (y) which is the next value after the sequence
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

# Set the sequence length (lookback period)
seq_length = 3  # Number of time steps to look back

# Generate input sequences and target values
X, y = create_sequences(scaled_data, seq_length)

# Split the data
train_size = int(len(X) * 0.7)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build the RNN model
model = Sequential([
    # Default activation function is 'tanh'
    SimpleRNN(50, input_shape=(seq_length, 1)),
    Dense(1)
])


# Build the RNN with relu, relu may perform better than tanh on simpler problems
# model = Sequential([
#     SimpleRNN(50, activation='relu', input_shape=(seq_length, 1)),
#     Dense(1)
# ])

model.compile(optimizer=Adam(learning_rate=0.01), loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.2, verbose=1)

# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)

print(f'Train Loss: {train_loss:.4f}')
print(f'Test Loss: {test_loss:.4f}')

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1))
test_predict = scaler.inverse_transform(test_predict)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate RMS
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0142 - val_loss: 0.0787
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0120 - val_loss: 0.0730
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0104 - val_loss: 0.0615
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0107 - val_loss: 0.0478
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0130 - val_loss: 0.0513
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0111 - val_loss: 0.0823
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0111 - val_loss: 0.1057
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0131 - val_loss: 0.0938
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0123 - val_loss: 0.0811
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0115 - val_loss: 0.0765
# Train Loss: 0.0256
# Test Loss: 0.2890
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# Train RMSE: 90.056
# Test RMSE: 302.517

# %%
import matplotlib.pyplot as plt

# Plot training and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# Load the data
df = pd.read_csv('crude-oil-price.csv', parse_dates=['date'], index_col='date')

# Use the 'price' column for modeling
df = df[['price']]

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# Create sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), 0])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

seq_length = 3  # Number of time steps to look back
X, y = create_sequences(scaled_data, seq_length)

# Split the data
train_size = int(len(X) * 0.7)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build the RNN model
model = Sequential([
    LSTM(50, input_shape=(seq_length, 1)),
    Dense(1)
])

model.compile(optimizer=Adam(learning_rate=0.01), loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.2, verbose=1)

# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)

print(f'Train Loss: {train_loss:.4f}')
print(f'Test Loss: {test_loss:.4f}')

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1))
test_predict = scaler.inverse_transform(test_predict)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate RMSE
train_rmse = np.sqrt(np.mean((train_predict - y_train_inv)**2))
test_rmse = np.sqrt(np.mean((test_predict - y_test_inv)**2))

print(f'Train RMSE: {train_rmse:.3f}')
print(f'Test RMSE: {test_rmse:.3f}')
# Out:
# Epoch 1/100
# C:\Users\wayne\anaconda3\envs\deeplearning-env\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0105 - val_loss: 0.0111
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010 - val_loss: 0.0145
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7730e-04 - val_loss: 0.0181
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0086e-04 - val_loss: 0.0108
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 0.0116
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0467e-04 - val_loss: 0.0130
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8216e-04 - val_loss: 0.0137
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3923e-04 - val_loss: 0.0113
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9601e-04 - val_loss: 0.0135
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9277e-04 - val_loss: 0.0170
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6437e-04 - val_loss: 0.0109
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4855e-04 - val_loss: 0.0111
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7667e-04 - val_loss: 0.0076
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0003e-04 - val_loss: 0.0104
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2566e-04 - val_loss: 0.0078
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6007e-04 - val_loss: 0.0103
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4686e-04 - val_loss: 0.0070
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2625e-04 - val_loss: 0.0105
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9661e-04 - val_loss: 0.0064
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6086e-04 - val_loss: 0.0138
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8278e-04 - val_loss: 0.0052
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8960e-04 - val_loss: 0.0104
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1430e-04 - val_loss: 0.0070
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6429e-04 - val_loss: 0.0053
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3790e-04 - val_loss: 0.0062
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4276e-04 - val_loss: 0.0064
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1188e-04 - val_loss: 0.0132
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9292e-04 - val_loss: 0.0058
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0348e-04 - val_loss: 0.0058
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0460e-04 - val_loss: 0.0080
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5056e-04 - val_loss: 0.0057
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7756e-04 - val_loss: 0.0117
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4324e-04 - val_loss: 0.0061
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8949e-04 - val_loss: 0.0062
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8343e-04 - val_loss: 0.0077
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6677e-04 - val_loss: 0.0060
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4419e-04 - val_loss: 0.0100
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0609e-04 - val_loss: 0.0057
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9585e-04 - val_loss: 0.0061
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1545e-04 - val_loss: 0.0073
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9191e-04 - val_loss: 0.0076
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4684e-04 - val_loss: 0.0055
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3078e-04 - val_loss: 0.0071
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7814e-04 - val_loss: 0.0071
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5057e-04 - val_loss: 0.0054
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0358e-04 - val_loss: 0.0058
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6042e-04 - val_loss: 0.0051
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6366e-04 - val_loss: 0.0058
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0072e-04 - val_loss: 0.0060
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4340e-04 - val_loss: 0.0053
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3552e-04 - val_loss: 0.0067
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8285e-04 - val_loss: 0.0080
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4458e-04 - val_loss: 0.0054
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3613e-04 - val_loss: 0.0092
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7142e-04 - val_loss: 0.0060
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6310e-04 - val_loss: 0.0059
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4459e-04 - val_loss: 0.0050
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0790e-04 - val_loss: 0.0057
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0918e-04 - val_loss: 0.0078
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0764e-04 - val_loss: 0.0053
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6879e-04 - val_loss: 0.0073
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2126e-04 - val_loss: 0.0053
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0215e-04 - val_loss: 0.0064
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1343e-04 - val_loss: 0.0053
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9739e-04 - val_loss: 0.0078
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9876e-04 - val_loss: 0.0053
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0171e-04 - val_loss: 0.0071
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7905e-04 - val_loss: 0.0059
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9768e-04 - val_loss: 0.0072
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7255e-04 - val_loss: 0.0063
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3884e-04 - val_loss: 0.0065
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0715e-04 - val_loss: 0.0059
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1928e-04 - val_loss: 0.0061
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2179e-04 - val_loss: 0.0064
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6570e-04 - val_loss: 0.0058
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9295e-04 - val_loss: 0.0053
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6085e-04 - val_loss: 0.0059
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0581e-04 - val_loss: 0.0053
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1648e-04 - val_loss: 0.0138
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2185e-04 - val_loss: 0.0063
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6201e-04 - val_loss: 0.0079
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8712e-04 - val_loss: 0.0052
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5390e-04 - val_loss: 0.0107
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5749e-04 - val_loss: 0.0053
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9213e-04 - val_loss: 0.0081
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2314e-04 - val_loss: 0.0058
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8330e-04 - val_loss: 0.0077
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5903e-04 - val_loss: 0.0055
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6267e-04 - val_loss: 0.0053
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1949e-04 - val_loss: 0.0057
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0099e-04 - val_loss: 0.0062
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0576e-04 - val_loss: 0.0055
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4422e-04 - val_loss: 0.0053
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2159e-04 - val_loss: 0.0057
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6684e-04 - val_loss: 0.0054
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9620e-04 - val_loss: 0.0112
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0255e-04 - val_loss: 0.0054
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3471e-04 - val_loss: 0.0060
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7880e-04 - val_loss: 0.0060
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5648e-04 - val_loss: 0.0059
# Train Loss: 0.0015
# Test Loss: 0.0034
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Train RMSE: 5.012
# Test RMSE: 7.578

# %%
import matplotlib.pyplot as plt

# Plot training and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot actual vs predicted values
plt.figure(figsize=(12, 6))
plt.plot(y_train_inv, label='Actual Train', marker='o', color='blue')
plt.plot(train_predict, label='Predicted Train', marker='x', color='orange')
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inv, label='Actual Test', marker='o', color='green')
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), test_predict, label='Predicted Test', marker='x', color='red')
plt.title('Actual vs Predicted Values')
plt.xlabel('Time Step')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('airpassengers.csv', parse_dates=['Month'], index_col='Month')

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# Create sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), 0])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

seq_length = 3  # Number of time steps to look back
X, y = create_sequences(scaled_data, seq_length)

# Split the data
train_size = int(len(X) * 0.7)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build the RNN model
model = Sequential([
    GRU(50, activation='relu', input_shape=(seq_length, 1)),
    Dense(1)
])

model.compile(optimizer=Adam(learning_rate=0.01), loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.2, verbose=1)

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1))
test_predict = scaler.inverse_transform(test_predict)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot training and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot actual vs predicted values
plt.figure(figsize=(12, 6))
plt.plot(y_train_inv, label='Actual Train', marker='o', color='blue')
plt.plot(train_predict, label='Predicted Train', marker='x', color='orange')
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inv, label='Actual Test', marker='o', color='green')
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), test_predict, label='Predicted Test', marker='x', color='red')
plt.title('Actual vs Predicted Values')
plt.xlabel('Time Step')
plt.ylabel('Number of Passengers')
plt.legend()
plt.grid(True)
plt.show()

# Calculate RMSE
train_rmse = np.sqrt(np.mean((train_predict - y_train_inv)**2))
test_rmse = np.sqrt(np.mean((test_predict - y_test_inv)**2))

print(f'Train RMSE: {train_rmse:.3f}')
print(f'Test RMSE: {test_rmse:.3f}')
# Out:
# Epoch 1/100
# C:\Users\wayne\anaconda3\envs\deeplearning-env\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.0291 - val_loss: 0.0106
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0074 - val_loss: 0.0264
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0054 - val_loss: 0.0061
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0035 - val_loss: 0.0123
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0027 - val_loss: 0.0053
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0035 - val_loss: 0.0067
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0033 - val_loss: 0.0054
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - val_loss: 0.0053
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0023 - val_loss: 0.0060
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0020 - val_loss: 0.0051
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0020 - val_loss: 0.0059
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022 - val_loss: 0.0051
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0023 - val_loss: 0.0055
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - val_loss: 0.0050
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0019 - val_loss: 0.0056
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0023 - val_loss: 0.0048
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021 - val_loss: 0.0052
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0020 - val_loss: 0.0048
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0019 - val_loss: 0.0051
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 0.0049
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - val_loss: 0.0046
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0021 - val_loss: 0.0052
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0021 - val_loss: 0.0044
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0053
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026 - val_loss: 0.0056
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0018 - val_loss: 0.0053
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0023 - val_loss: 0.0047
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019 - val_loss: 0.0044
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 0.0043
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0041
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0018 - val_loss: 0.0041
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - val_loss: 0.0042
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015 - val_loss: 0.0040
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - val_loss: 0.0046
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014 - val_loss: 0.0039
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - val_loss: 0.0041
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0037
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - val_loss: 0.0039
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 0.0052
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 0.0054
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0018 - val_loss: 0.0048
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 0.0046
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0013 - val_loss: 0.0038
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 0.0033
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 0.0041
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 0.0041
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 0.0038
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0043
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0041
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - val_loss: 0.0042
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0039
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - val_loss: 0.0037
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011 - val_loss: 0.0039
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - val_loss: 0.0037
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0039
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - val_loss: 0.0037
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0040
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - val_loss: 0.0037
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0039
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013 - val_loss: 0.0039
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 0.0039
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0043
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0013 - val_loss: 0.0036
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0013 - val_loss: 0.0040
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0038
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Train RMSE: 22.173
# Test RMSE: 53.781

# %% [markdown]
# The RMSE (Root Mean Square Error) provides a measure of how far off the model's predictions are from the actual values in the same units as the data. Here's what the RMSE tells us for each dataset:
#
# ## Air Passengers Dataset
# - Train RMSE: 22.581
# - Test RMSE: 59.456
#
# ### Interpretation:
#   The RMSE indicates that, on average, the model's predictions differ from the actual number of passengers by about 22.6 on the training set and 59.5 on the test set. This means the model is more accurate on the training data than on unseen data.
#
#
# ## Crude Oil Dataset
# - Train RMSE: 5.300
# - Test RMSE: 7.350
# ### Interpretation:
#   The RMSE suggests that the model's predictions for oil prices are off by about $5.30 on the training set and $7.35 on the test set. This indicates a relatively good fit, with predictions being close to actual prices.
#
#
# ## Shampoo Sales Dataset
# - Train RMSE: 79.627
# - Test RMSE: 251.452
# ### Interpretation:
#   The RMSE shows that the model's predictions for shampoo sales are off by about 79.6 units on the training set and 251.5 units on the test set. This large error suggests the model is struggling to accurately predict sales, especially on unseen data.
#
# ## General Insights
# - Lower RMSE: Indicates more accurate predictions.
# - Higher RMSE: Suggests larger prediction errors.
# - Comparison: The difference between train and test RMSE can indicate overfitting (if the test RMSE is much higher than the train RMSE).
# - In summary, RMSE provides a direct measure of prediction accuracy in the context of the specific units of each dataset (e.g., passengers, dollars, sales units).
