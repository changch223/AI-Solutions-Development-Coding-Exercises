# %% [markdown]
# # Task: Classify human activities based on the sensor data

# %% [markdown]
# ## Part 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ## Read Data

# %%
data_main = list()

dum_data = pd.read_csv('total_acc_x_train.txt', header=None, delim_whitespace=True)
data_main.append(dum_data)
dum_data = pd.read_csv('total_acc_y_train.txt', header=None, delim_whitespace=True)
data_main.append(dum_data)
dum_data = pd.read_csv('total_acc_z_train.txt', header=None, delim_whitespace=True)
data_main.append(dum_data)

dum_data = pd.read_csv('body_acc_x_train.txt', header=None, delim_whitespace=True)
data_main.append(dum_data)
dum_data = pd.read_csv('body_acc_y_train.txt', header=None, delim_whitespace=True)
data_main.append(dum_data)
dum_data = pd.read_csv('body_acc_z_train.txt', header=None, delim_whitespace=True)

data_main.append(dum_data)
dum_data = pd.read_csv('body_gyro_x_train.txt', header=None, delim_whitespace=True)
data_main.append(dum_data)
dum_data = pd.read_csv('body_gyro_y_train.txt', header=None, delim_whitespace=True)
data_main.append(dum_data)
dum_data = pd.read_csv('body_gyro_z_train.txt', header=None, delim_whitespace=True)
data_main.append(dum_data)
# Out:
# C:\Users\wayne\AppData\Local\Temp\ipykernel_25164\1424277980.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dum_data = pd.read_csv('total_acc_x_train.txt', header=None, delim_whitespace=True)
# C:\Users\wayne\AppData\Local\Temp\ipykernel_25164\1424277980.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dum_data = pd.read_csv('total_acc_y_train.txt', header=None, delim_whitespace=True)
# C:\Users\wayne\AppData\Local\Temp\ipykernel_25164\1424277980.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dum_data = pd.read_csv('total_acc_z_train.txt', header=None, delim_whitespace=True)
# C:\Users\wayne\AppData\Local\Temp\ipykernel_25164\1424277980.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dum_data = pd.read_csv('body_acc_x_train.txt', header=None, delim_whitespace=True)
# C:\Users\wayne\AppData\Local\Temp\ipykernel_25164\1424277980.py:12: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dum_data = pd.read_csv('body_acc_y_train.txt', header=None, delim_whitespace=True)
# C:\Users\wayne\AppData\Local\Temp\ipykernel_25164\1424277980.py:14: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dum_data = pd.read_csv('body_acc_z_train.txt', header=None, delim_whitespace=True)
# C:\Users\wayne\AppData\Local\Temp\ipykernel_25164\1424277980.py:17: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dum_data = pd.read_csv('body_gyro_x_train.txt', header=None, delim_whitespace=True)
# C:\Users\wayne\AppData\Local\Temp\ipykernel_25164\1424277980.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dum_data = pd.read_csv('body_gyro_y_train.txt', header=None, delim_whitespace=True)
# C:\Users\wayne\AppData\Local\Temp\ipykernel_25164\1424277980.py:21: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dum_data = pd.read_csv('body_gyro_z_train.txt', header=None, delim_whitespace=True)

# %% [markdown]
# ## Data Preprocessing

# %%
len(data_main)
# Out:
# 9

# %%
data_main[0].head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  1.012817  1.022833  1.022028  1.017877  1.023680  1.016974  1.017746
# 1  1.018851  1.022380  1.020781  1.020218  1.021344  1.020522  1.019790
# 2  1.023127  1.021882  1.019178  1.015861  1.012893  1.016451  1.020331
# 3  1.017682  1.018149  1.019854  1.019880  1.019121  1.020479  1.020595
# 4  1.019952  1.019616  1.020933  1.023061  1.022242  1.020867  1.021939
#
#         7         8         9    ...       118       119       120       121  \
# 0  1.019263  1.016417  1.020745  ...  1.020981  1.018065  1.019638  1.020017
# 1  1.019216  1.018307  1.017996  ...  1.019291  1.019258  1.020736  1.020950
# 2  1.020266  1.021759  1.018649  ...  1.020304  1.021516  1.019417  1.019312
# 3  1.016340  1.010611  1.009013  ...  1.021295  1.022934  1.022183  1.021637
# 4  1.022300  1.022302  1.022254  ...  1.022687  1.023670  1.019899  1.017381
#
#         122       123       124       125       126       127
# 0  1.018766  1.019815  1.019290  1.018445  1.019372  1.021171
# 1  1.020491  1.018685  1.015660  1.014788  1.016499  1.017849
# 2  1.019448  1.019434  1.019916  1.021041  1.022935  1.022019
# 3  1.020598  1.018887  1.019161  1.019916  1.019602  1.020735
# 4  1.020389  1.023884  1.021753  1.019425  1.018896  1.016787
#
# [5 rows x 128 columns]

# %%
data_main[0].shape
# Out:
# (7352, 128)

# %%
data_main[1].shape
# Out:
# (7352, 128)

# %%
# make it a 3D aray with featuers
data = np.dstack(data_main)

# %%
data.shape
# Out:
# (7352, 128, 9)

# %%
# read the target values
y_data = pd.read_csv('y_train.txt', header=None, delim_whitespace=True)
# Out:
# C:\Users\wayne\AppData\Local\Temp\ipykernel_25164\638418738.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   y_data = pd.read_csv('y_train.txt', header=None, delim_whitespace=True)

# %%
y_data.shape
# Out:
# (7352, 1)

# %%
y_data.head()
# Out:
#    0
# 0  5
# 1  5
# 2  5
# 3  5
# 4  5

# %%
y_data.iloc[:, 0].unique()
# Out:
# array([5, 4, 6, 1, 3, 2], dtype=int64)

# %%
# Train and test set data
x_train = data[0:6000, :, :]
y_train = y_data [0:6000]

# %%
x_test = data[6000:, :, :]
y_test = y_data [6000:]

# %%
# one hot encode the y train data
y_train_hot = to_categorical(y_train)
y_test_hot = to_categorical(y_test)

# %%
y_train_hot.shape
# Out:
# (6000, 7)

# %%
# delete category zero, no such category
y_train_hot = y_train_hot[:, 1:7]
y_test_hot = y_test_hot[:, 1:7]

# %%
# get important sizes and dimensions
n_sample = x_train.shape[0]
time_steps = x_train.shape[1]
n_features = x_train.shape[2]
n_outputs = y_train_hot.shape[1]

# %%
# Visualising some of the signal
test_sample = 150
data_plot = x_train[test_sample, :, 8]
plt.plot(data_plot)
plt.xlabel('Time')
plt.ylabel('signal value')
plt.legend()
plt.show()
# Out:
# C:\Users\wayne\AppData\Local\Temp\ipykernel_25164\1147584201.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## Part 2.  Building the RNN

# %%
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from tensorflow import keras

# %%
# Initialising the RNN
my_classifier = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
my_classifier.add(LSTM(units = 20, return_sequences = True,
                       input_shape = (time_steps, n_features)))
my_classifier.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
#my_classifier.add(LSTM(units = 30, return_sequences = True))
#my_classifier.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
#my_classifier.add(LSTM(units = 20, return_sequences = True))
#my_classifier.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
my_classifier.add(LSTM(units = 20))
my_classifier.add(Dropout(0.2))

# Adding the output layer
my_classifier.add(Dense(units = n_outputs, activation='softmax'))

# Compiling the RNN
my_classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy',
                     metrics = ['accuracy'])
# Out:
# C:\Users\wayne\anaconda3\envs\deeplearning-env\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
my_classifier.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128, 20)        │         2,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128, 20)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 20)             │         3,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │           126 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,806 (22.68 KB)
#  Trainable params: 5,806 (22.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fitting the RNN to the Training set
history = my_classifier.fit(x_train, y_train_hot, epochs = 10,
                           batch_size = 32, validation_split=0.1)
# Out:
# Epoch 1/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - accuracy: 0.4307 - loss: 1.4292 - val_accuracy: 0.6417 - val_loss: 0.8291
# Epoch 2/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 12s 70ms/step - accuracy: 0.6542 - loss: 0.8231 - val_accuracy: 0.8167 - val_loss: 0.5619
# Epoch 3/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - accuracy: 0.6701 - loss: 0.6925 - val_accuracy: 0.7533 - val_loss: 0.5324
# Epoch 4/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 12s 70ms/step - accuracy: 0.6718 - loss: 0.6596 - val_accuracy: 0.4750 - val_loss: 1.8627
# Epoch 5/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - accuracy: 0.5566 - loss: 1.1122 - val_accuracy: 0.7400 - val_loss: 0.5758
# Epoch 6/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 12s 72ms/step - accuracy: 0.6831 - loss: 0.6749 - val_accuracy: 0.7517 - val_loss: 0.5235
# Epoch 7/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.6955 - loss: 0.6365 - val_accuracy: 0.7700 - val_loss: 0.5060
# Epoch 8/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 12s 74ms/step - accuracy: 0.7256 - loss: 0.5828 - val_accuracy: 0.7733 - val_loss: 0.5325
# Epoch 9/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - accuracy: 0.7487 - loss: 0.5994 - val_accuracy: 0.7583 - val_loss: 0.5391
# Epoch 10/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 12s 72ms/step - accuracy: 0.7924 - loss: 0.5179 - val_accuracy: 0.8783 - val_loss: 0.3557

# %% [markdown]
# ## save the final model

# %%
# save the final model
my_classifier.save('sig_classifier.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# to load keras model
from keras.models import load_model
my_classifier = keras.models.load_model("sig_classifier.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## Part 3

# %%
# evaluate model
_, accuracy = my_classifier.evaluate(x_test, y_test_hot, batch_size=32)
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8133 - loss: 0.6965

# %%
# Making the predictions and visualising the results
y_test_pred_hot = my_classifier.predict(x_test)
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step

# %%
#y_test_pred_hot [ y_test_pred_hot>0.5] = 1
#y_test_pred_hot [ y_test_pred_hot<0.5] = 0

# inverse the "to_categorical"
y_test_pred = np.argmax(y_test_pred_hot, axis=1) + 1

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_test_pred)

# %%
cm
# Out:
# array([[197,   1,   7,   0,   0,   0],
#        [  8, 192,  16,   0,   0,   0],
#        [ 82,  11, 107,   0,   0,   0],
#        [  1,   0,   0, 188,  38,   0],
#        [  2,   0,   0,  72, 173,   0],
#        [  0,  37,   0,   0,   0, 220]], dtype=int64)

# %%
# list all the data in history
print(history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %% [markdown]
# ## Plot the accuracy for both train and validation set

# %%
# Plot the accuracy for both train and validation set
plt.subplots() # open a new plot
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# ## Plot the loss for both train and validation set

# %%
# Plot the loss for both train and validation set
plt.subplots() # open a new plot
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# ## Add more Layer

# %%
# Initialising the RNN
my_classifier = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
my_classifier.add(LSTM(units = 16, return_sequences = True,
                       input_shape = (time_steps, n_features)))
my_classifier.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
my_classifier.add(LSTM(units = 32, return_sequences = True))
my_classifier.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
my_classifier.add(LSTM(units = 16, return_sequences = True))
my_classifier.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
my_classifier.add(LSTM(units = 16))
my_classifier.add(Dropout(0.2))

# Adding the output layer
my_classifier.add(Dense(units = n_outputs, activation='softmax'))

# Compiling the RNN
my_classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy',
                     metrics = ['accuracy'])
# Out:
# C:\Users\wayne\anaconda3\envs\deeplearning-env\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
my_classifier.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 128, 16)        │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128, 32)        │         6,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 128, 16)        │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 16)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           102 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,286 (51.90 KB)
#  Trainable params: 13,286 (51.90 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fitting the RNN to the Training set
history = my_classifier.fit(x_train, y_train_hot, epochs = 10,
                           batch_size = 32, validation_split=0.1)
# Out:
# Epoch 1/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 31s 141ms/step - accuracy: 0.4085 - loss: 1.4717 - val_accuracy: 0.7067 - val_loss: 0.8201
# Epoch 2/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - accuracy: 0.6315 - loss: 0.8747 - val_accuracy: 0.7217 - val_loss: 0.6627
# Epoch 3/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 23s 137ms/step - accuracy: 0.7294 - loss: 0.6863 - val_accuracy: 0.8250 - val_loss: 0.4352
# Epoch 4/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 24s 139ms/step - accuracy: 0.7625 - loss: 0.5818 - val_accuracy: 0.7233 - val_loss: 0.6616
# Epoch 5/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 24s 144ms/step - accuracy: 0.7688 - loss: 0.5524 - val_accuracy: 0.8517 - val_loss: 0.3473
# Epoch 6/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 24s 142ms/step - accuracy: 0.7993 - loss: 0.4624 - val_accuracy: 0.8617 - val_loss: 0.3445
# Epoch 7/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 24s 141ms/step - accuracy: 0.7845 - loss: 0.5112 - val_accuracy: 0.8867 - val_loss: 0.3529
# Epoch 8/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 25s 147ms/step - accuracy: 0.7832 - loss: 0.5001 - val_accuracy: 0.8783 - val_loss: 0.3301
# Epoch 9/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 24s 144ms/step - accuracy: 0.8132 - loss: 0.4083 - val_accuracy: 0.8567 - val_loss: 0.4288
# Epoch 10/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 24s 139ms/step - accuracy: 0.8289 - loss: 0.3742 - val_accuracy: 0.9233 - val_loss: 0.2621

# %%
# Plot the accuracy for both train and validation set
plt.subplots() # open a new plot
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.show()

# %%
# Plot the loss for both train and validation set
plt.subplots() # open a new plot
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.show()
