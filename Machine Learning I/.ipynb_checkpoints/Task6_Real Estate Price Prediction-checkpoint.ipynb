# %% [markdown]
# # Task6: Predicting Real Estate House Prices

# %% [markdown]
# ## This task is provided to test your understanding of building a Linear Regression model for a provided dataset

# %% [markdown]
# ### Dataset: Real_estate.csv

# %% [markdown]
# ### Import the necessary libraries
# #### Hint: Also import seaborn

# %%
import pandas as pd
dt = pd.read_csv('Real estate.csv')

# %% [markdown]
# ### Read the csv data into a pandas dataframe and display the first 5 samples

# %%
dt.head(5)
# Out:
#    No  X1 transaction date  ...  X6 longitude  Y house price of unit area
# 0   1             2012.917  ...     121.54024                        37.9
# 1   2             2012.917  ...     121.53951                        42.2
# 2   3             2013.583  ...     121.54391                        47.3
# 3   4             2013.500  ...     121.54391                        54.8
# 4   5             2012.833  ...     121.54245                        43.1
#
# [5 rows x 8 columns]

# %% [markdown]
# ### Show more information about the dataset

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %% [markdown]
# ### Find how many samples are there and how many columns are there in the dataset

# %%
dt.shape
# Out:
# (414, 8)

# %% [markdown]
# ### What are the features available in the dataset?

# %%
dt.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %% [markdown]
# ### Check if any features have missing data

# %%
dt.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %% [markdown]
# ### Group all the features as dependent features in X

# %%
X = dt.iloc[:,:-1]
X
# Out:
#       No  X1 transaction date  ...  X5 latitude  X6 longitude
# 0      1             2012.917  ...     24.98298     121.54024
# 1      2             2012.917  ...     24.98034     121.53951
# 2      3             2013.583  ...     24.98746     121.54391
# 3      4             2013.500  ...     24.98746     121.54391
# 4      5             2012.833  ...     24.97937     121.54245
# ..   ...                  ...  ...          ...           ...
# 409  410             2013.000  ...     24.94155     121.50381
# 410  411             2012.667  ...     24.97433     121.54310
# 411  412             2013.250  ...     24.97923     121.53986
# 412  413             2013.000  ...     24.96674     121.54067
# 413  414             2013.500  ...     24.97433     121.54310
#
# [414 rows x 7 columns]

# %% [markdown]
# ### Group feature(s) as independent features in y

# %%
y = dt.iloc[:,-1]
y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %% [markdown]
# ### Split the dataset into train and test data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 1)

# %% [markdown]
# ### Choose the model (Linear Regression)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Create an Estimator object

# %%
regressor = LinearRegression()

# %% [markdown]
# ### Train the model

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Apply the model

# %%
y_pred = regressor.predict(X_test)

y_pred
# Out:
# array([34.59222454, 47.58673483, 20.9226481 , 12.49402832, 43.11887361,
#        34.53739706, 30.94528506, 45.32577595, 38.04839075, 13.90217198,
#        11.89791644, 38.52611287, 31.88063097, 45.37604685, 50.84658168,
#        36.2862735 , 44.41072387, 45.22203001, 30.05273304, 43.75888331,
#        51.29456053, 28.42367787, 40.02214039, 46.83612492, 45.84974629,
#        27.92864195, 31.22197429, 47.76028543, 46.28854703, 15.07952064,
#        33.75569025, 34.83403033, 42.32056056, 44.63278564, 48.22580741,
#        12.97087505, 41.19586968, 41.23713034, 38.99845431, 13.34108478,
#        39.17706813, 24.42380144, 54.59173411, 36.60841823, 34.90462826,
#        38.87349258, 30.70013923, 39.54325265, 45.86276573, 34.25812241,
#        11.34870326, 44.60912585, 44.90742037, 13.80958428, 49.00623946,
#        42.27434654, 44.23307525, 39.39850242, 38.07681462, 39.67756938,
#        25.07802274, 40.22903165, 35.23138718, 12.73839662, 40.28227559,
# ...

# %% [markdown]
# ### Display the coefficients

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [-1.09659640e-03  5.69815368e+00 -2.49757004e-01 -4.94908683e-03
#   1.07369954e+00  2.26802763e+02 -3.62816002e+01]
# -12680.960064789277

# %% [markdown]
# ### Find how well the trained model did with testing data

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.7061990777417202

# %% [markdown]
# ### Plot House Age Vs Price
# #### Hint: Use regplot in sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset
df = pd.read_csv('Real estate.csv')  # Replace with your dataset path

# Create a scatter plot with a regression line
plt.figure(figsize=(8, 6))
sns.regplot(x='X2 house age', y='Y house price of unit area', data=df, scatter_kws={'alpha': 0.6}, line_kws={'color': 'blue'})
plt.xlabel('X2 house age')
plt.ylabel('Y house price of unit area')
plt.title('Plot House Age Vs Price')
plt.show()

# %% [markdown]
# ### Plot Distance to MRT station Vs Price

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset
df = pd.read_csv('Real estate.csv')  # Replace with the path to your dataset

# Create a scatter plot with a regression line
plt.figure(figsize=(8, 6))
sns.regplot(x='Y house price of unit area', y='X3 distance to the nearest MRT station', 
            data=df, scatter_kws={'alpha': 0.6}, line_kws={'color': 'blue'})
plt.xlabel('Y house price of unit area')
plt.ylabel('X3 distance to the nearest MRT station')
plt.title('Plot Distance to MRT station Vs Price')
plt.show()

# %% [markdown]
# ### Plot Number of Convienience Stores Vs Price

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset
df = pd.read_csv('Real estate.csv')  # Replace with the path to your dataset

# Create a scatter plot with a regression line
plt.figure(figsize=(8, 6))
sns.regplot(x='Y house price of unit area', y='X4 number of convenience stores', 
            data=df, scatter_kws={'alpha': 0.6}, line_kws={'color': 'blue'})
plt.xlabel('Y house price of unit area')
plt.ylabel('X4 number of convenience stores')
plt.title('Plot Number of Convenience Stores Vs Price')
plt.show()
